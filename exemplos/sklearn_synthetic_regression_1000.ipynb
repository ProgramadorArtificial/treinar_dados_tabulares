# %% [markdown]
# # Sklearn
# Notebook pensando para facilitar e agiliar o treinamento de Machine Learning, sendo necessário, em grande parte das vezes, somente alterar o caminho do dataset e o tipo (classificador ou regressão).

# %%
import warnings
warnings.filterwarnings('ignore')

import copy
import json
import math
import time
import pickle

import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Preparar Dataset

# %%
def preprocess_data(df, target_cols, max_unique_values=10, window_size=1):
    """
    Preprocess dataset, converting string columns to number and identifying numeric, categorical, and date columns.
    Adds a window of historical rows to the data.

    Args:
        df (DataFrame): DataFrame with data to analyze.
        target_cols (list): All target columns to not add in numeric, categorical, or date feature lists.
        max_unique_values (int): Maximum number of unique values to consider a numeric column as categorical.
        window_size (int): Number of previous rows to include for each row.

    Returns:
        df_copy (DataFrame): Processed DataFrame with transformations applied.
        num_col_names (list): List of numeric feature column names.
        cat_col_names (list): List of categorical feature column names.
        date_col_names (list): List of date feature column names.
        mappings (dict): Mapping of original categorical values (or target columns) to transformed numeric values.
    """
    # Create a copy so as not to alter the original DataFrame
    df_copy = df.copy()

    # Remove lines with null values
    df_copy = df_copy.dropna()
    
    # Identify categorical and numeric columns
    cat_col_names = df_copy.select_dtypes(include=['object', 'category']).columns.tolist()
    num_col_names = df_copy.select_dtypes(include=['number']).columns.tolist()
    date_col_names = []

    # Identify columns that are dates
    for col in df.columns:
        if df[col].dtype in ['object', 'string']:  # Only check object/string columns
            try:
                # Attempt to convert the column to datetime
                pd.to_datetime(df[col], errors='raise')
                if col not in target_cols:  # Avoid considering target columns as date columns
                    date_col_names.append(col)
            except (ValueError, TypeError):
                pass

    # Identify numeric columns that are categorical
    potential_categorical = []
    for col in num_col_names:
        if col not in target_cols and df_copy[col].nunique() <= max_unique_values:
            potential_categorical.append(col)

    cat_col_names += potential_categorical

    # Remove target columns from the lists
    num_col_names = [col for col in num_col_names if col not in potential_categorical + target_cols]
    cat_col_names = [col for col in cat_col_names if col not in target_cols]
    
    mappings = {}
    label_encoders = {}

    # Convert string columns to category and create a mapping (old value -> new value)
    for col in cat_col_names + target_cols:
        if df_copy[col].dtype not in ['int64', 'float64']:
            le = LabelEncoder()
            df_copy[col] = le.fit_transform(df_copy[col])
            mappings[col] = dict(zip(le.classes_, le.transform(le.classes_)))
            label_encoders[col] = le
            # Convert values to int (otherwise will raise error if save as json)
            for key, value in mappings[col].items():
                mappings[col][key] = int(value)
        #else:
        #    mappings[col] = {int(val): int(val) for val in df_copy[col].unique()}

    # Add historical data based on window_size
    if window_size > 1:
        historical_features = []
        for i in range(window_size - 1, 0, -1):  # Criar features lag, do mais antigo ao mais recente
            shifted = df_copy.drop(columns=target_cols, errors='ignore').shift(i).add_suffix(f'_lag_{i}')
            historical_features.append(shifted)
        
        # Concatenate the lags to the left and keep the current values
        df_copy = pd.concat(historical_features + [df_copy], axis=1)
    
        # Remove NaNs columns created by shifts
        df_copy = df_copy.dropna()
    
        # Add lags
        num_col_lags = [f'{col}_lag_{i}' for i in range(window_size - 1, 0, -1) for col in num_col_names]
        cat_col_lags = [f'{col}_lag_{i}' for i in range(window_size - 1, 0, -1) for col in cat_col_names]
        date_col_lags = [f'{col}_lag_{i}' for i in range(window_size - 1, 0, -1) for col in date_col_names]
        mappings_lags = {}
        for col, value in mappings.items():
            for i in range(window_size - 1, 0, -1):
                mappings_lags[f'{col}_lag_{i}'] = value
    
        # Update main columns + lags columns
        num_col_names = num_col_lags + num_col_names
        cat_col_names = cat_col_lags + cat_col_names
        date_col_names = date_col_lags + date_col_names
        mappings = {**mappings_lags, **mappings}
    
    return df_copy, num_col_names, cat_col_names, date_col_names, mappings

# %%
df = pd.read_csv('dataset/synthetic_dataset_reg_1000.csv')
model_type = 'regressor'  # classifier or regressor
window_size = 1
df
# Out:
#       feature_1 feature_2   feature_3   feature_4  feature_5  feature_6  \
# 0     66.770774         A  129.519443  157.649826   6.255495   0.828523
# 1     -2.221535         E  140.304091  216.744647   5.713914   0.355732
# 2     77.488190         A  166.952399  312.938945   5.267239   0.960411
# 3     57.321113         E   88.365298   89.727234   6.706377  -0.895494
# 4     36.569191         D  143.379356  118.911115   6.242576   1.525309
# ..          ...       ...         ...         ...        ...        ...
# 995  103.368938         B  186.348599   86.930012   5.304516   1.636305
# 996   90.724062         C  105.858206  332.872938   7.254402  -0.141445
# 997   93.945082         C   96.920963  134.339603   6.679430  -0.193135
# 998   49.022551         C  141.195125  138.956040   6.623024  -1.847212
# 999   65.396854         C  169.895414  205.841059   4.312114  -0.040263
#
#      feature_7  feature_8    target
# 0         1.10   0.656228  2.432088
# 1         1.20   0.698121  0.522399
# 2         1.10   0.957005  8.291973
# 3         1.20   0.757337 -0.253508
# 4         0.95   0.965473  2.611435
# ..         ...        ...       ...
# 995       0.90   0.837241  9.203443
# 996       1.05   0.663071  5.213301
# 997       1.05   0.985183  4.534213
# 998       1.05   0.718735  1.150318
# 999       1.05   0.999962  4.097842
#
# [1000 rows x 9 columns]

# %%
target_cols = ['target']
# Aplicar o pré-processamento
df, num_col_names, cat_col_names, date_col_names, category_mappings = preprocess_data(df, target_cols, max_unique_values=10, window_size=window_size)
col_names_order = df.columns.tolist()

# %%
df
# Out:
#       feature_1  feature_2   feature_3   feature_4  feature_5  feature_6  \
# 0     66.770774          0  129.519443  157.649826   6.255495   0.828523
# 1     -2.221535          4  140.304091  216.744647   5.713914   0.355732
# 2     77.488190          0  166.952399  312.938945   5.267239   0.960411
# 3     57.321113          4   88.365298   89.727234   6.706377  -0.895494
# 4     36.569191          3  143.379356  118.911115   6.242576   1.525309
# ..          ...        ...         ...         ...        ...        ...
# 995  103.368938          1  186.348599   86.930012   5.304516   1.636305
# 996   90.724062          2  105.858206  332.872938   7.254402  -0.141445
# 997   93.945082          2   96.920963  134.339603   6.679430  -0.193135
# 998   49.022551          2  141.195125  138.956040   6.623024  -1.847212
# 999   65.396854          2  169.895414  205.841059   4.312114  -0.040263
#
#      feature_7  feature_8    target
# 0         1.10   0.656228  2.432088
# 1         1.20   0.698121  0.522399
# 2         1.10   0.957005  8.291973
# 3         1.20   0.757337 -0.253508
# 4         0.95   0.965473  2.611435
# ..         ...        ...       ...
# 995       0.90   0.837241  9.203443
# 996       1.05   0.663071  5.213301
# 997       1.05   0.985183  4.534213
# 998       1.05   0.718735  1.150318
# 999       1.05   0.999962  4.097842
#
# [1000 rows x 9 columns]

# %%
print(f'''col_names_order: {col_names_order}
num_col_names: {num_col_names}
cat_col_names: {cat_col_names}
date_col_names: {date_col_names}
target_cols: {target_cols}
category_mappings: {category_mappings}''')
# Out:
# col_names_order: ['feature_1', 'feature_2', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_7', 'feature_8', 'target']
# num_col_names: ['feature_1', 'feature_3', 'feature_4', 'feature_5', 'feature_6', 'feature_8']
# cat_col_names: ['feature_2', 'feature_7']
# date_col_names: []
# target_cols: ['target']
# category_mappings: {'feature_2': {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5}}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature_1  1000 non-null   float64
#  1   feature_2  1000 non-null   int64
#  2   feature_3  1000 non-null   float64
#  3   feature_4  1000 non-null   float64
#  4   feature_5  1000 non-null   float64
#  5   feature_6  1000 non-null   float64
#  6   feature_7  1000 non-null   float64
#  7   feature_8  1000 non-null   float64
#  8   target     1000 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 70.4 KB

# %%
if model_type == 'classifier':
    print(df[target_cols].value_counts())

# %% [markdown]
# ### Dataset Split

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, random_state=42, test_size=0.3)

# %%
y_train = train[target_cols]
x_train = train.drop(target_cols, axis=1)

# %%
y_test = test[target_cols]
x_test = test.drop(target_cols, axis=1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
#from skelarn.preprocessing import MinMaxScaler

#scaler = preprocessing.MinMaxScaler()

# %%
x_train
# Out:
#      feature_1  feature_2   feature_3   feature_4  feature_5  feature_6  \
# 541  61.282779          2   85.727014  213.671389   7.009344  -0.371707
# 440  69.430790          5   58.897796   26.538786   6.473074   0.672116
# 482  21.105169          5  113.376505  209.845314   6.577277  -0.355478
# 422  19.743462          4  162.253355  270.986057   5.511892   0.692929
# 778  10.050194          4   96.372959   76.846148   5.796292   1.889467
# ..         ...        ...         ...         ...        ...        ...
# 106  17.257347          2  169.329248   84.846722   6.611299  -1.463970
# 270  88.104266          2  185.927139  149.604856   6.335173  -1.190243
# 860  82.893603          2  161.649061   65.341401   6.443603  -1.774072
# 435  88.530205          2   77.883583  338.549363   7.200380   1.332697
# 102  23.207490          4  122.077783   98.748634   6.148170  -0.032532
#
#      feature_7  feature_8
# 541       1.05   0.599594
# 440       0.85   0.370614
# 482       0.85   0.131220
# 422       1.20   0.531248
# 778       1.20   0.937108
# ..         ...        ...
# 106       1.05   0.502549
# 270       1.05   0.320141
# 860       1.05   0.696194
# 435       1.05   0.885851
# 102       1.20   0.288537
#
# [700 rows x 8 columns]

# %%
x_train[num_col_names] = scaler.fit_transform(x_train[num_col_names])
x_train = x_train.values.tolist()
x_train
# Out:
# [[0.4026975263820124,
#   2.0,
#   -0.38207855705615773,
#   0.5693399110718501,
#   1.0569213109102236,
#   -0.36530240695529104,
#   1.05,
#   -0.15086827171241127],
#  [0.6827828393798894,
#   5.0,
#   -0.8679629446924538,
#   -1.3032711688479608,
#   0.4648274300267772,
#   0.7019806544030626,
#   0.85,
#   -0.8710559383072759],
#  [-0.9783952906823954,
#   5.0,
#   0.11866117880549201,
#   0.5310528844529745,
#   0.5798776349542373,
#   -0.34870827838306934,
#   0.85,
#   -1.6240001556568429],
#   1.5977079493087385,
#   1.2,
#   0.8370069018692953],
#  [0.947183876585243,
#   5.0,
#   1.672307173833881,
#   -1.032101749134629,
#   0.1482212316322433,
#   0.29781752526795835,
#   0.85,
#   -0.7246492902498648],
#  [-0.4410358994501036,
#   0.0,
#   0.21311771560337478,
#   -0.429003241914268,
#   -0.1833068878341475,
#   -1.5131957620622725,
#   1.1,
#   -0.47596706408019857],
#  [-0.6321243482105751,
#   4.0,
#   0.43315280920721067,
#   -1.0839242758008414,
#   0.29303461336497744,
#   0.05969144240819653,
#   1.2,
#   -1.8120133226575084],
#  [1.29134464195496,
#   1.0,
#   1.6574790627972014,
#   -1.3618956554855162,
#   -0.14940731349800396,
#   -1.3041029047319366,
#   0.9,
#   0.8763118719960942],
#  [1.2800309675211337,
#   0.0,
#   0.2573467125131079,
#   0.013134310339030581,
#   0.33061166173965256,
#   -0.04451156971024161,
#   1.1,
#   -1.1624074185623618],
#  [0.6635398563557021,
#   3.0,
#   1.6698887870825572,
#   0.4853689981148014,
#   0.6707709289323872,
#   0.8815418041515565,
#   0.95,
#   0.42601317943070294],
#  [0.9771552930865569,
#   1.0,
#   0.7143828677878918,
#   -0.21399559877083799,
#   0.33470533161133265,
#   0.7041120926446522,
#   0.9,
#   0.5490847835702913],
#  [-0.25282220310545106,
#   5.0,
#   0.18244244657550718,
#   0.6863681686363853,
#   -1.2668524601453766,
#   1.9683682774855178,
#   0.85,
#   0.9202957791248091],
#  [-1.541775279032235,
#   4.0,
#   0.30371378122206527,
#   -0.5222635100068146,
#   0.4339646811705699,
#   0.18659939412219068,
#   1.2,
#   1.0792966894939702],
#  [-0.9500713669813762,
#   3.0,
#   -1.0902796600091023,
#   1.8648472878207532,
#   -0.7779540897515299,
#   1.7729628550101493,
#   0.95,
#   -0.2779523742577766],
#  [-0.5790328801922395,
#   2.0,
#   -0.9614820457876709,
#   -0.28632666064232304,
#   1.2824224405722686,
#   0.31351455985556764,
#   1.05,
#   -0.05584273426858746],
#  [-1.6799906447298467,
#   3.0,
#   -1.2520969483361228,
#   -0.7583418364764964,
#   0.1253820013186864,
#   -1.0303114602542396,
#   0.95,
#   0.7406697046507399],
#  [1.7542471829299502,
#   3.0,
#   1.2423468175304049,
#   -0.5384896412157706,
#   -0.8226947960339612,
#   1.1289182359196965,
#   0.95,
#   -0.17499654030847614]]

# %% [markdown]
# ### Variáveis de entrada mais importantes para as tomadas de decisão do modelo

# %% [markdown]
# #### Random Forest

# %%
if model_type == 'classifier':
    from sklearn.ensemble import RandomForestClassifier
    
    # Realizando Random Forest para identificar a relevância das variáveis.
    # Feature Extraction by Random Forest
    model = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                           criterion='gini', max_depth=None, max_features=3, # nao sei o que eh este max_features
                           max_leaf_nodes=None, max_samples=None,
                           min_impurity_decrease=0.0,
                           min_samples_leaf=1, min_samples_split=2,
                           min_weight_fraction_leaf=0.0, n_estimators=10,
                           n_jobs=None, oob_score=False, random_state=None,
                           verbose=0, warm_start=False)
    model.fit(x_train, y_train)
    
    feature_importances_val = model.feature_importances_
    pd.options.display.float_format = '{:.10f}'.format
    
    x_pd = pd.DataFrame(x_train, columns=col_names_order[:-1])
    feature_importances = pd.DataFrame(feature_importances_val,
                                       index = x_pd.columns,
                                       columns=['importance']).sort_values('importance', ascending = False)
    print(f'Accuracy: {model.score(x_test, y_test) * 100}')
    print(feature_importances)

# %% [markdown]
# #### DecisionTree

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error


if model_type == 'classifier':
    from sklearn.tree import DecisionTreeClassifier
    from sklearn.metrics import confusion_matrix
    model = DecisionTreeClassifier(max_depth=3)
else:
    from sklearn.tree import DecisionTreeRegressor
    model = DecisionTreeRegressor(max_depth=3)    

model.fit(x_train, y_train)

if model_type == 'classifier':
    print(f'Accuracy: {model.score(x_test, y_test) * 100}')
    print(f'Confusion matrix: {confusion_matrix(model.predict(x_test), y_test)}')
else:
    print(f'MSE: {mean_squared_error(model.predict(x_test), y_test)}')

importance = model.feature_importances_
for idx, score in enumerate(importance):
    print(f'{idx}-{df.keys()[idx]}, Score: {score}')

plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# MSE: 13.448519985388725
# 0-feature_1, Score: 0.09703918261365733
# 1-feature_2, Score: 0.0
# 2-feature_3, Score: 0.38404560056780607
# 3-feature_4, Score: 0.19648046220124923
# 4-feature_5, Score: 0.0
# 5-feature_6, Score: 0.0
# 6-feature_7, Score: 0.0
# 7-feature_8, Score: 0.3224347546172873

# %% [markdown]
# ## Treinar diversos estimators disponíveis no Sklearn
# https://scikit-learn.org/stable/supervised_learning.html

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.utils.discovery.all_estimators.html#sklearn.utils.discovery.all_estimators
from sklearn.utils import all_estimators

# classifier, regressor, cluster, transformer
estimators = all_estimators(type_filter=model_type)

all_estimators = {}
for name, estimator in estimators:
    try:
        print('Appending', name)
        est = estimator()
        all_estimators[name] = est
    except Exception as e:
        print(e)
# Out:
# Appending ARDRegression
# Appending AdaBoostRegressor
# Appending BaggingRegressor
# Appending BayesianRidge
# Appending CCA
# Appending DecisionTreeRegressor
# Appending DummyRegressor
# Appending ElasticNet
# Appending ElasticNetCV
# Appending ExtraTreeRegressor
# Appending ExtraTreesRegressor
# Appending GammaRegressor
# Appending GaussianProcessRegressor
# Appending GradientBoostingRegressor
# Appending HistGradientBoostingRegressor
# Appending HuberRegressor
# Appending IsotonicRegression
# Appending KNeighborsRegressor
# Appending KernelRidge
# Appending Lars
# Appending LarsCV
# Appending Lasso
# Appending LassoCV
# Appending LassoLars
# Appending LassoLarsCV
# Appending LassoLarsIC
# Appending LinearRegression
# Appending LinearSVR
# Appending MLPRegressor
# Appending MultiOutputRegressor
# MultiOutputRegressor.__init__() missing 1 required positional argument: 'estimator'
# Appending MultiTaskElasticNet
# Appending MultiTaskElasticNetCV
# Appending MultiTaskLasso
# Appending MultiTaskLassoCV
# Appending NuSVR
# Appending OrthogonalMatchingPursuit
# Appending OrthogonalMatchingPursuitCV
# Appending PLSCanonical
# Appending PLSRegression
# Appending PassiveAggressiveRegressor
# Appending PoissonRegressor
# Appending QuantileRegressor
# Appending RANSACRegressor
# Appending RadiusNeighborsRegressor
# Appending RandomForestRegressor
# Appending RegressorChain
# _BaseChain.__init__() missing 1 required positional argument: 'base_estimator'
# Appending Ridge
# Appending RidgeCV
# Appending SGDRegressor
# Appending SVR
# Appending StackingRegressor
# StackingRegressor.__init__() missing 1 required positional argument: 'estimators'
# Appending TheilSenRegressor
# Appending TransformedTargetRegressor
# Appending TweedieRegressor
# Appending VotingRegressor
# VotingRegressor.__init__() missing 1 required positional argument: 'estimators'

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_squared_error

def run_sklearn_estimators(estimators, x_train, y_train, x_test, y_test, model_type='classifier'):
    if model_type == 'classifier':
        best_acc = ['', 0.0]  # [estimator_name, accuracy]
    else:
        best_acc = ['', 99999.0]  # [estimator_name, error]
    
    for estimator_name, estimator in estimators.items():
        try:
            print(f'##### {estimator_name} #####')

            estimator.fit(x_train, y_train)
            
            if model_type == 'classifier':
                print('Train ACC: %.3f%%' % (estimator.score(x_train, y_train) * 100.00))
            else:
                train_mse = mean_squared_error(estimator.predict(x_train), y_train)
                print('Train MSE: %.3f' % (train_mse))
                print(f'Train inference error (RMSE): ±{math.sqrt(train_mse)}')
            
            if model_type == 'classifier':
                test_acc = estimator.score(x_test, y_test) * 100.00
                print('Test ACC: %.3f%%' % (test_acc))
            else:
                test_mse = mean_squared_error(estimator.predict(x_test), y_test)
                print('Test MSE: %.3f' % (test_mse))
                print(f'Test inference error (RMSE): ±{math.sqrt(test_mse)}')
            print()
    
            if model_type == 'classifier' and test_acc > best_acc[1]:
                best_acc = [estimator_name, test_acc]
            elif model_type == 'regressor' and test_mse < best_acc[1]:
                best_acc = [estimator_name, test_mse, math.sqrt(test_mse)]
            
            # Confusion Matrix
            if model_type == 'classifier':
                preds = estimator.predict(x_test)
                matrix = confusion_matrix(y_test, preds)
                print('Confusion Matrix Test:')
                print(matrix)
        except Exception as e:
            print(f'Error ({estimator_name}): {e}')

    print('########## Best Estimator ##########')
    print(best_acc)
    
    return estimators, best_acc[0]

# %%
tic = time.time()
estimators_trained, best_estimator_name = run_sklearn_estimators(
    all_estimators,
    x_train,
    y_train,
    x_test,
    y_test,
    model_type
)
print(f'Total time: {time.time() - tic}')
# Out:
# ##### ARDRegression #####
# Train MSE: 5.873
# Train inference error (RMSE): ±2.4233948131676253
# Test MSE: 7.030
# Test inference error (RMSE): ±2.6514803432805394
#
# ##### AdaBoostRegressor #####
# Train MSE: 4.154
# Train inference error (RMSE): ±2.0381811081656473
# Test MSE: 8.024
# Test inference error (RMSE): ±2.8326986585026943
#
# ##### BaggingRegressor #####
# Train MSE: 0.967
# Train inference error (RMSE): ±0.9831648712489933
# Test MSE: 5.778
# Test inference error (RMSE): ±2.403815638081039
#
# ##### BayesianRidge #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.421953459008041
# Test MSE: 7.049
# Test inference error (RMSE): ±2.6549027497385635
#
# ##### CCA #####
# Error (CCA): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### DecisionTreeRegressor #####
# Train MSE: 0.000
# Train inference error (RMSE): ±0.0
# Test MSE: 9.571
# Test inference error (RMSE): ±3.093655613114727
#
# ##### DummyRegressor #####
# Train MSE: 20.162
# Train inference error (RMSE): ±4.490186371856764
# Test MSE: 22.192
# Test inference error (RMSE): ±4.710802273108114
#
# ##### ElasticNet #####
# Train MSE: 10.113
# Train inference error (RMSE): ±3.1801686041758113
# Test MSE: 11.832
# Test inference error (RMSE): ±3.4398398640519887
#
# ##### ElasticNetCV #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.421945081015883
# Test MSE: 7.048
# Test inference error (RMSE): ±2.6548567480489544
#
# ##### ExtraTreeRegressor #####
# Train MSE: 0.000
# Train inference error (RMSE): ±0.0
# Test MSE: 15.754
# Test inference error (RMSE): ±3.969092497319382
#
# ##### ExtraTreesRegressor #####
# Train MSE: 0.000
# Train inference error (RMSE): ±6.09290882801753e-15
# Test MSE: 4.247
# Test inference error (RMSE): ±2.0608666760518206
#
# ##### GammaRegressor #####
# Error (GammaRegressor): Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
# ##### GaussianProcessRegressor #####
# Train MSE: 0.000
# Train inference error (RMSE): ±3.517747793900642e-10
# Test MSE: 6.323
# Test inference error (RMSE): ±2.5144757089938174
#
# ##### GradientBoostingRegressor #####
# Train MSE: 0.650
# Train inference error (RMSE): ±0.8065062753015338
# Test MSE: 3.593
# Test inference error (RMSE): ±1.8954231128385188
#
# ##### HistGradientBoostingRegressor #####
# Train MSE: 0.749
# Train inference error (RMSE): ±0.8656779373687523
# Test MSE: 3.619
# Test inference error (RMSE): ±1.9024039866323665
#
# ##### HuberRegressor #####
# Train MSE: 6.139
# Train inference error (RMSE): ±2.477701472739484
# Test MSE: 7.215
# Test inference error (RMSE): ±2.6860007771733674
#
# ##### IsotonicRegression #####
# Error (IsotonicRegression): Isotonic regression input X should be a 1d array or 2d array with 1 feature
# ##### KNeighborsRegressor #####
# Train MSE: 3.943
# Train inference error (RMSE): ±1.9857221014535549
# Test MSE: 5.797
# Test inference error (RMSE): ±2.4076149491496404
#
# ##### KernelRidge #####
# Train MSE: 5.896
# Train inference error (RMSE): ±2.428250986753236
# Test MSE: 7.066
# Test inference error (RMSE): ±2.6582355858435314
#
# ##### Lars #####
# Train MSE: 5.864
# Train inference error (RMSE): ±2.4216207444107494
# Test MSE: 7.049
# Test inference error (RMSE): ±2.654974086274436
#
# ##### LarsCV #####
# Train MSE: 5.864
# Train inference error (RMSE): ±2.4216207444107494
# Test MSE: 7.049
# Test inference error (RMSE): ±2.654974086274436
#
# ##### Lasso #####
# Train MSE: 11.244
# Train inference error (RMSE): ±3.3531369118947985
# Test MSE: 13.378
# Test inference error (RMSE): ±3.6576194752955926
#
# ##### LassoCV #####
# Train MSE: 5.865
# Train inference error (RMSE): ±2.4216958605532275
# Test MSE: 7.048
# Test inference error (RMSE): ±2.6548223600853063
#
# ##### LassoLars #####
# Train MSE: 11.244
# Train inference error (RMSE): ±3.3531366875984507
# Test MSE: 13.378
# Test inference error (RMSE): ±3.6576192613625316
#
# ##### LassoLarsCV #####
# Train MSE: 5.864
# Train inference error (RMSE): ±2.4216207444107494
# Test MSE: 7.049
# Test inference error (RMSE): ±2.654974086274436
#
# ##### LassoLarsIC #####
# Train MSE: 5.864
# Train inference error (RMSE): ±2.4216207444107494
# Test MSE: 7.049
# Test inference error (RMSE): ±2.654974086274436
#
# ##### LinearRegression #####
# Train MSE: 5.864
# Train inference error (RMSE): ±2.421620744410749
# Test MSE: 7.049
# Test inference error (RMSE): ±2.654974086274436
#
# ##### LinearSVR #####
# Train MSE: 6.193
# Train inference error (RMSE): ±2.488497821607341
# Test MSE: 7.240
# Test inference error (RMSE): ±2.690740708003243
#
# ##### MLPRegressor #####
# Train MSE: 2.006
# Train inference error (RMSE): ±1.4162629563836167
# Test MSE: 3.035
# Test inference error (RMSE): ±1.7422230203638598
#
# ##### MultiTaskElasticNet #####
# Train MSE: 10.113
# Train inference error (RMSE): ±3.1801686041758113
# Test MSE: 11.832
# Test inference error (RMSE): ±3.439839864051989
#
# ##### MultiTaskElasticNetCV #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.421945081015883
# Test MSE: 7.048
# Test inference error (RMSE): ±2.6548567480489544
#
# ##### MultiTaskLasso #####
# Train MSE: 11.244
# Train inference error (RMSE): ±3.3531369118947985
# Test MSE: 13.378
# Test inference error (RMSE): ±3.6576194752955926
#
# ##### MultiTaskLassoCV #####
# Train MSE: 5.865
# Train inference error (RMSE): ±2.4216958605532275
# Test MSE: 7.048
# Test inference error (RMSE): ±2.6548223600853063
#
# ##### NuSVR #####
# Train MSE: 3.954
# Train inference error (RMSE): ±1.9883699206375112
# Test MSE: 5.001
# Test inference error (RMSE): ±2.236203311338901
#
# ##### OrthogonalMatchingPursuit #####
# Train MSE: 15.309
# Train inference error (RMSE): ±3.91264958045368
# Test MSE: 19.691
# Test inference error (RMSE): ±4.437423958747689
#
# ##### OrthogonalMatchingPursuitCV #####
# Train MSE: 6.107
# Train inference error (RMSE): ±2.471307945380167
# Test MSE: 7.295
# Test inference error (RMSE): ±2.700833984369021
#
# ##### PLSCanonical #####
# Error (PLSCanonical): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### PLSRegression #####
# Train MSE: 5.864
# Train inference error (RMSE): ±2.421660044506571
# Test MSE: 7.044
# Test inference error (RMSE): ±2.6540554567028303
#
# ##### PassiveAggressiveRegressor #####
# Train MSE: 7.361
# Train inference error (RMSE): ±2.7130305164797788
# Test MSE: 8.322
# Test inference error (RMSE): ±2.884794767779155
#
# ##### PoissonRegressor #####
# Error (PoissonRegressor): Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# ##### QuantileRegressor #####
# Train MSE: 20.242
# Train inference error (RMSE): ±4.499063426260528
# Test MSE: 21.955
# Test inference error (RMSE): ±4.685609581263041
#
# ##### RANSACRegressor #####
# Train MSE: 6.530
# Train inference error (RMSE): ±2.5554510416887064
# Test MSE: 7.430
# Test inference error (RMSE): ±2.7257954484547784
#
# ##### RadiusNeighborsRegressor #####
# Train MSE: 0.240
# Train inference error (RMSE): ±0.4895012078491109
# Error (RadiusNeighborsRegressor): Input contains NaN.
# ##### RandomForestRegressor #####
# Train MSE: 0.626
# Train inference error (RMSE): ±0.7914321575731432
# Test MSE: 5.210
# Test inference error (RMSE): ±2.282605928565407
#
# ##### Ridge #####
# Train MSE: 5.864
# Train inference error (RMSE): ±2.4216706549909053
# Test MSE: 7.048
# Test inference error (RMSE): ±2.6548314028164635
#
# ##### RidgeCV #####
# Train MSE: 5.864
# Train inference error (RMSE): ±2.4216706549909044
# Test MSE: 7.048
# Test inference error (RMSE): ±2.65483140281621
#
# ##### SGDRegressor #####
# Train MSE: 5.935
# Train inference error (RMSE): ±2.4361131523394888
# Test MSE: 7.157
# Test inference error (RMSE): ±2.675323372468256
#
# ##### SVR #####
# Train MSE: 4.003
# Train inference error (RMSE): ±2.000799746375871
# Test MSE: 4.838
# Test inference error (RMSE): ±2.199655351888307
#
# ##### TheilSenRegressor #####
# Train MSE: 6.171
# Train inference error (RMSE): ±2.4841846921541704
# Test MSE: 7.452
# Test inference error (RMSE): ±2.729819415331045
#
# ##### TransformedTargetRegressor #####
# Train MSE: 5.864
# Train inference error (RMSE): ±2.421620744410749
# Test MSE: 7.049
# Test inference error (RMSE): ±2.654974086274436
#
# ##### TweedieRegressor #####
# Train MSE: 9.512
# Train inference error (RMSE): ±3.0842079814539334
# Test MSE: 11.127
# Test inference error (RMSE): ±3.335760752303996
#
# ########## Best Estimator ##########
# ['MLPRegressor', 3.0353410526857703, 1.7422230203638598]
# Total time: 1.7337806224822998

# %%
estimators_trained[best_estimator_name]
# Out:
# MLPRegressor()

# %% [markdown]
# ### Save Estimator

# %%
# Save
pickle.dump(estimators_trained[best_estimator_name], open('results/estimator_sklearn.sav', 'wb'))

# Scaler
pickle.dump(scaler, open('results/scaler.pkl','wb'))

# Save columns names and informations
data_to_save = {
    'col_names_order': col_names_order,
    'num_col_names': num_col_names,
    'cat_col_names': cat_col_names,
    'date_col_names': date_col_names,
    'target_cols': target_cols,
    'category_mappings': category_mappings,
    'window_size': window_size
}
with open('results/columns_metadata_sklearn.json', 'w') as json_file:
    json.dump(data_to_save, json_file, indent=4)

# %% [markdown]
# ## Stacking estimators
# Classificador: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingClassifier.html#sklearn.ensemble.StackingClassifier
#
# Regressor: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingRegressor.html#sklearn.ensemble.StackingRegressor

# %%
# https://scikit-learn.org/stable/modules/generated/sklearn.utils.discovery.all_estimators.html#sklearn.utils.discovery.all_estimators
from sklearn.utils import all_estimators

# classifier, regressor, cluster, transformer
estimators = all_estimators(type_filter=model_type)

all_estimators = {}
for name, estimator in estimators:
    try:
        print('Appending', name)
        est = estimator()
        all_estimators[name] = est
    except Exception as e:
        print(e)
# Out:
# Appending ARDRegression
# Appending AdaBoostRegressor
# Appending BaggingRegressor
# Appending BayesianRidge
# Appending CCA
# Appending DecisionTreeRegressor
# Appending DummyRegressor
# Appending ElasticNet
# Appending ElasticNetCV
# Appending ExtraTreeRegressor
# Appending ExtraTreesRegressor
# Appending GammaRegressor
# Appending GaussianProcessRegressor
# Appending GradientBoostingRegressor
# Appending HistGradientBoostingRegressor
# Appending HuberRegressor
# Appending IsotonicRegression
# Appending KNeighborsRegressor
# Appending KernelRidge
# Appending Lars
# Appending LarsCV
# Appending Lasso
# Appending LassoCV
# Appending LassoLars
# Appending LassoLarsCV
# Appending LassoLarsIC
# Appending LinearRegression
# Appending LinearSVR
# Appending MLPRegressor
# Appending MultiOutputRegressor
# MultiOutputRegressor.__init__() missing 1 required positional argument: 'estimator'
# Appending MultiTaskElasticNet
# Appending MultiTaskElasticNetCV
# Appending MultiTaskLasso
# Appending MultiTaskLassoCV
# Appending NuSVR
# Appending OrthogonalMatchingPursuit
# Appending OrthogonalMatchingPursuitCV
# Appending PLSCanonical
# Appending PLSRegression
# Appending PassiveAggressiveRegressor
# Appending PoissonRegressor
# Appending QuantileRegressor
# Appending RANSACRegressor
# Appending RadiusNeighborsRegressor
# Appending RandomForestRegressor
# Appending RegressorChain
# _BaseChain.__init__() missing 1 required positional argument: 'base_estimator'
# Appending Ridge
# Appending RidgeCV
# Appending SGDRegressor
# Appending SVR
# Appending StackingRegressor
# StackingRegressor.__init__() missing 1 required positional argument: 'estimators'
# Appending TheilSenRegressor
# Appending TransformedTargetRegressor
# Appending TweedieRegressor
# Appending VotingRegressor
# VotingRegressor.__init__() missing 1 required positional argument: 'estimators'

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

from sklearn.ensemble import StackingRegressor
from sklearn.linear_model import RidgeCV
from sklearn.metrics import mean_squared_error

def run_sklearn_estimators_with_stacking(estimators, x_train, y_train, x_test, y_test, model_type):
    if model_type == 'classifier':
        best_acc = ['', 0.0]  # [estimator_name, accuracy]
    else:
        best_acc = ['', 99999.0]  # [estimator_name, error]
    estimators_stacked_trained = {}
    
    idx = 0
    for estimator_name, estimator in estimators.items():
        count = 0
        for estimator_name2, estimator2 in estimators.items():
            if count <= idx:
                count += 1
                continue
            try:
                print(f'##### {estimator_name} - {estimator_name2} #####')

                if model_type == 'classifier':
                    stack = StackingClassifier([(estimator_name, copy.deepcopy(estimator)), (estimator_name2, copy.deepcopy(estimator2))],
                                              final_estimator=LogisticRegression())
                else:
                    stack = StackingRegressor([(estimator_name, copy.deepcopy(estimator)), (estimator_name2, copy.deepcopy(estimator2))],
                                              final_estimator=RidgeCV())

                stack.fit(x_train, y_train)
                
                if model_type == 'classifier':
                    print('Train ACC: %.3f%%' % (stack.score(x_train, y_train) * 100.00))
                else:
                    train_mse = mean_squared_error(stack.predict(x_train), y_train)
                    print('Train MSE: %.3f' % (train_mse))
                    print(f'Train inference error (RMSE): ±{math.sqrt(train_mse)}')
                
                if model_type == 'classifier':
                    test_acc = stack.score(x_test, y_test) * 100.00
                    print('Test ACC: %.3f%%' % (test_acc))
                else:
                    test_mse = mean_squared_error(stack.predict(x_test), y_test)
                    print('Test MSE: %.3f' % (test_mse))
                    print(f'Test inference error (RMSE): ±{math.sqrt(test_mse)}')
        
                if model_type == 'classifier' and test_acc > best_acc[1]:
                    best_acc = [f'{estimator_name}-{estimator_name2}', test_acc]
                elif model_type == 'regressor' and test_mse < best_acc[1]:
                    best_acc = [f'{estimator_name}-{estimator_name2}', test_mse, math.sqrt(test_mse)]
                
                # Confusion Matrix
                if model_type == 'classifier':
                    preds = stack.predict(x_test)
                    matrix = confusion_matrix(y_test, preds)
                    print('Confusion Matrix Test:')
                    print(matrix)

                estimators_stacked_trained[f'{estimator_name}-{estimator_name2}'] = copy.deepcopy(stack)
            except Exception as e:
                print(f'Error ({estimator_name}-{estimator_name2}): {e}')
                continue
        
        idx += 1

    print('########## Best Estimator ##########')
    print(best_acc)
    
    return estimators_stacked_trained, best_acc[0]

# %%
tic = time.time()
estimators_stacked_trained, best_stacked_estimator_name = run_sklearn_estimators_with_stacking(
    all_estimators,
    x_train,
    y_train,
    x_test,
    y_test,
    model_type
)
print(f'Total time: {time.time() - tic}')
# Out:
# ##### ARDRegression - AdaBoostRegressor #####
# Train MSE: 3.111
# Train inference error (RMSE): ±1.7637849358785533
# Test MSE: 5.791
# Test inference error (RMSE): ±2.4063734674981907
# ##### ARDRegression - BaggingRegressor #####
# Train MSE: 1.828
# Train inference error (RMSE): ±1.3520723433168957
# Test MSE: 5.493
# Test inference error (RMSE): ±2.3438198940784356
# ##### ARDRegression - BayesianRidge #####
# Train MSE: 5.874
# Train inference error (RMSE): ±2.423624049073377
# Test MSE: 7.085
# Test inference error (RMSE): ±2.661683274032103
# ##### ARDRegression - CCA #####
# Error (ARDRegression-CCA): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### ARDRegression - DecisionTreeRegressor #####
# Train MSE: 4.176
# Train inference error (RMSE): ±2.0436177217882543
# Test MSE: 6.091
# Test inference error (RMSE): ±2.467959648560224
# ##### ARDRegression - DummyRegressor #####
# Train MSE: 5.875
# Train inference error (RMSE): ±2.423843270669991
# Test MSE: 7.039
# Test inference error (RMSE): ±2.6530315193569147
# ##### ARDRegression - ElasticNet #####
# Train MSE: 5.874
# Train inference error (RMSE): ±2.423558688772382
# Test MSE: 7.023
# Test inference error (RMSE): ±2.6500949133443736
# ##### ARDRegression - ElasticNetCV #####
# Train MSE: 5.874
# Train inference error (RMSE): ±2.423643513912305
# Test MSE: 7.087
# Test inference error (RMSE): ±2.6621064874480047
# ##### ARDRegression - ExtraTreeRegressor #####
# Train MSE: 3.340
# Train inference error (RMSE): ±1.8276503266886392
# Test MSE: 6.449
# Test inference error (RMSE): ±2.539512496031932
# ##### ARDRegression - ExtraTreesRegressor #####
# Train MSE: 0.521
# Train inference error (RMSE): ±0.7217684757990744
# Test MSE: 4.075
# Test inference error (RMSE): ±2.0186057596004807
# ##### ARDRegression - GammaRegressor #####
# Error (ARDRegression-GammaRegressor): Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
# ##### ARDRegression - GaussianProcessRegressor #####
# Train MSE: 1.096
# Train inference error (RMSE): ±1.0471337813284924
# Test MSE: 4.670
# Test inference error (RMSE): ±2.1609738339673754
# ##### ARDRegression - GradientBoostingRegressor #####
# Train MSE: 0.658
# Train inference error (RMSE): ±0.8111250210963135
# Test MSE: 3.469
# Test inference error (RMSE): ±1.8624474816084984
# ##### ARDRegression - HistGradientBoostingRegressor #####
# Train MSE: 0.769
# Train inference error (RMSE): ±0.8766611705705201
# Test MSE: 3.474
# Test inference error (RMSE): ±1.8638854004249163
# ##### ARDRegression - HuberRegressor #####
# Train MSE: 5.892
# Train inference error (RMSE): ±2.427329807557514
# Test MSE: 7.016
# Test inference error (RMSE): ±2.648700861985916
# ##### ARDRegression - IsotonicRegression #####
# Error (ARDRegression-IsotonicRegression): Isotonic regression input X should be a 1d array or 2d array with 1 feature
# ##### ARDRegression - KNeighborsRegressor #####
# Train MSE: 3.648
# Train inference error (RMSE): ±1.909912178400567
# Test MSE: 4.862
# Test inference error (RMSE): ±2.2049593698972734
# ##### ARDRegression - KernelRidge #####
# Train MSE: 5.876
# Train inference error (RMSE): ±2.424051712068575
# Test MSE: 7.044
# Test inference error (RMSE): ±2.6540763853582505
# ##### ARDRegression - Lars #####
# Train MSE: 5.870
# Train inference error (RMSE): ±2.4227134063992692
# Test MSE: 7.082
# Test inference error (RMSE): ±2.661187820363313
# ##### ARDRegression - LarsCV #####
# Train MSE: 5.870
# Train inference error (RMSE): ±2.4227134063992692
# Test MSE: 7.082
# Test inference error (RMSE): ±2.661187820363313
# ##### ARDRegression - Lasso #####
# Train MSE: 5.876
# Train inference error (RMSE): ±2.423993930545051
# Test MSE: 6.996
# Test inference error (RMSE): ±2.6450003643877245
# ##### ARDRegression - LassoCV #####
# Train MSE: 5.871
# Train inference error (RMSE): ±2.4229549362612666
# Test MSE: 7.085
# Test inference error (RMSE): ±2.6617201951745395
# ##### ARDRegression - LassoLars #####
# Train MSE: 5.876
# Train inference error (RMSE): ±2.4239939310266383
# Test MSE: 6.996
# Test inference error (RMSE): ±2.6450003612527557
# ##### ARDRegression - LassoLarsCV #####
# Train MSE: 5.870
# Train inference error (RMSE): ±2.4227134063992692
# Test MSE: 7.082
# Test inference error (RMSE): ±2.661187820363313
# ##### ARDRegression - LassoLarsIC #####
# Train MSE: 5.869
# Train inference error (RMSE): ±2.4226674269127253
# Test MSE: 7.040
# Test inference error (RMSE): ±2.6533391307800898
# ##### ARDRegression - LinearRegression #####
# Train MSE: 5.870
# Train inference error (RMSE): ±2.422713406399099
# Test MSE: 7.082
# Test inference error (RMSE): ±2.661187820362786
# ##### ARDRegression - LinearSVR #####
# Train MSE: 5.880
# Train inference error (RMSE): ±2.4249369568547103
# Test MSE: 7.017
# Test inference error (RMSE): ±2.6490488361804223
# ##### ARDRegression - MLPRegressor #####
# Train MSE: 1.884
# Train inference error (RMSE): ±1.372534341715111
# Test MSE: 2.838
# Test inference error (RMSE): ±1.6845166837587435
# ##### ARDRegression - MultiTaskElasticNet #####
# Error (ARDRegression-MultiTaskElasticNet): For mono-task outputs, use ElasticNet
# ##### ARDRegression - MultiTaskElasticNetCV #####
# Error (ARDRegression-MultiTaskElasticNetCV): For mono-task outputs, use ElasticNetCVCV
# ##### ARDRegression - MultiTaskLasso #####
# Error (ARDRegression-MultiTaskLasso): For mono-task outputs, use ElasticNet
# ##### ARDRegression - MultiTaskLassoCV #####
# Error (ARDRegression-MultiTaskLassoCV): For mono-task outputs, use LassoCVCV
# ##### ARDRegression - NuSVR #####
# Train MSE: 3.381
# Train inference error (RMSE): ±1.8386530044558222
# Test MSE: 4.077
# Test inference error (RMSE): ±2.019260843487821
# ##### ARDRegression - OrthogonalMatchingPursuit #####
# Train MSE: 5.875
# Train inference error (RMSE): ±2.423787244927992
# Test MSE: 7.010
# Test inference error (RMSE): ±2.6476196666411145
# ##### ARDRegression - OrthogonalMatchingPursuitCV #####
# Train MSE: 5.888
# Train inference error (RMSE): ±2.426466250136702
# Test MSE: 7.051
# Test inference error (RMSE): ±2.655294511073022
# ##### ARDRegression - PLSCanonical #####
# Error (ARDRegression-PLSCanonical): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### ARDRegression - PLSRegression #####
# Train MSE: 5.872
# Train inference error (RMSE): ±2.4232690753159476
# Test MSE: 7.087
# Test inference error (RMSE): ±2.6622247956024947
# ##### ARDRegression - PassiveAggressiveRegressor #####
# Train MSE: 5.917
# Train inference error (RMSE): ±2.432505173286718
# Test MSE: 7.051
# Test inference error (RMSE): ±2.6553719788712904
# ##### ARDRegression - PoissonRegressor #####
# Error (ARDRegression-PoissonRegressor): Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# ##### ARDRegression - QuantileRegressor #####
# Train MSE: 5.875
# Train inference error (RMSE): ±2.423823090505685
# Test MSE: 7.038
# Test inference error (RMSE): ±2.652947390007643
# ##### ARDRegression - RANSACRegressor #####
# Train MSE: 5.877
# Train inference error (RMSE): ±2.424325700134619
# Test MSE: 7.032
# Test inference error (RMSE): ±2.6517025316155163
# ##### ARDRegression - RadiusNeighborsRegressor #####
# Error (ARDRegression-RadiusNeighborsRegressor): Input X contains NaN.
# _RidgeGCV does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# ##### ARDRegression - RandomForestRegressor #####
# Train MSE: 1.015
# Train inference error (RMSE): ±1.0075336940294701
# Test MSE: 4.800
# Test inference error (RMSE): ±2.190810354589822
# ##### ARDRegression - Ridge #####
# Train MSE: 5.871
# Train inference error (RMSE): ±2.4230556531635767
# Test MSE: 7.086
# Test inference error (RMSE): ±2.661893805025359
# ##### ARDRegression - RidgeCV #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.4220804958625473
# Test MSE: 7.040
# Test inference error (RMSE): ±2.6533336349791887
# ##### ARDRegression - SGDRegressor #####
# Train MSE: 5.955
# Train inference error (RMSE): ±2.440340571616854
# Test MSE: 7.169
# Test inference error (RMSE): ±2.677498760963253
# ##### ARDRegression - SVR #####
# Train MSE: 3.465
# Train inference error (RMSE): ±1.8615121949975437
# Test MSE: 3.949
# Test inference error (RMSE): ±1.987087897441589
# ##### ARDRegression - TheilSenRegressor #####
# Train MSE: 5.892
# Train inference error (RMSE): ±2.4274322922891858
# Test MSE: 7.064
# Test inference error (RMSE): ±2.6579003294121355
# ##### ARDRegression - TransformedTargetRegressor #####
# Train MSE: 5.870
# Train inference error (RMSE): ±2.422713406399099
# Test MSE: 7.082
# Test inference error (RMSE): ±2.661187820362786
# ##### ARDRegression - TweedieRegressor #####
# Train MSE: 5.873
# Train inference error (RMSE): ±2.423519410344757
# Test MSE: 7.038
# Test inference error (RMSE): ±2.6528797942052735
# ##### AdaBoostRegressor - BaggingRegressor #####
# Train MSE: 1.109
# Train inference error (RMSE): ±1.0530761100549226
# Test MSE: 5.399
# Test inference error (RMSE): ±2.323553827076634
# ##### AdaBoostRegressor - BayesianRidge #####
# Train MSE: 3.091
# Train inference error (RMSE): ±1.7580716976468906
# Test MSE: 5.661
# Test inference error (RMSE): ±2.3793282984841895
# ##### AdaBoostRegressor - CCA #####
# Error (AdaBoostRegressor-CCA): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### AdaBoostRegressor - DecisionTreeRegressor #####
# Train MSE: 2.438
# Train inference error (RMSE): ±1.5612897032236208
# Test MSE: 5.898
# Test inference error (RMSE): ±2.4286443552208334
# ##### AdaBoostRegressor - DummyRegressor #####
# Train MSE: 3.312
# Train inference error (RMSE): ±1.8199573279387882
# Test MSE: 7.029
# Test inference error (RMSE): ±2.651155543851914
# ##### AdaBoostRegressor - ElasticNet #####
# Train MSE: 3.150
# Train inference error (RMSE): ±1.7747638263655974
# Test MSE: 6.178
# Test inference error (RMSE): ±2.485615421705733
# ##### AdaBoostRegressor - ElasticNetCV #####
# Train MSE: 3.004
# Train inference error (RMSE): ±1.7331849083335689
# Test MSE: 5.732
# Test inference error (RMSE): ±2.3942370511053763
# ##### AdaBoostRegressor - ExtraTreeRegressor #####
# Train MSE: 1.854
# Train inference error (RMSE): ±1.3617147720924527
# Test MSE: 5.738
# Test inference error (RMSE): ±2.395499282197319
# ##### AdaBoostRegressor - ExtraTreesRegressor #####
# Train MSE: 0.600
# Train inference error (RMSE): ±0.7746167954044211
# Test MSE: 3.758
# Test inference error (RMSE): ±1.9385022816857358
# ##### AdaBoostRegressor - GammaRegressor #####
# Error (AdaBoostRegressor-GammaRegressor): Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
# ##### AdaBoostRegressor - GaussianProcessRegressor #####
# Train MSE: 1.200
# Train inference error (RMSE): ±1.095223576151918
# Test MSE: 4.460
# Test inference error (RMSE): ±2.1118684951953446
# ##### AdaBoostRegressor - GradientBoostingRegressor #####
# Train MSE: 0.664
# Train inference error (RMSE): ±0.8148004095462568
# Test MSE: 3.372
# Test inference error (RMSE): ±1.8362780521889175
# ##### AdaBoostRegressor - HistGradientBoostingRegressor #####
# Train MSE: 0.669
# Train inference error (RMSE): ±0.8181463773299119
# Test MSE: 3.498
# Test inference error (RMSE): ±1.8702967168225844
# ##### AdaBoostRegressor - HuberRegressor #####
# Train MSE: 2.948
# Train inference error (RMSE): ±1.7171012030522974
# Test MSE: 5.537
# Test inference error (RMSE): ±2.35298420278003
# ##### AdaBoostRegressor - IsotonicRegression #####
# Error (AdaBoostRegressor-IsotonicRegression): Isotonic regression input X should be a 1d array or 2d array with 1 feature
# ##### AdaBoostRegressor - KNeighborsRegressor #####
# Train MSE: 2.132
# Train inference error (RMSE): ±1.4602433678920501
# Test MSE: 4.612
# Test inference error (RMSE): ±2.147530382840219
# ##### AdaBoostRegressor - KernelRidge #####
# Train MSE: 3.035
# Train inference error (RMSE): ±1.7419859190421065
# Test MSE: 5.668
# Test inference error (RMSE): ±2.3808548321267415
# ##### AdaBoostRegressor - Lars #####
# Train MSE: 3.245
# Train inference error (RMSE): ±1.8014827949549423
# Test MSE: 5.979
# Test inference error (RMSE): ±2.4451306539676505
# ##### AdaBoostRegressor - LarsCV #####
# Train MSE: 2.875
# Train inference error (RMSE): ±1.6954829716504376
# Test MSE: 5.670
# Test inference error (RMSE): ±2.3812171063851104
# ##### AdaBoostRegressor - Lasso #####
# Train MSE: 3.269
# Train inference error (RMSE): ±1.807901537639804
# Test MSE: 6.528
# Test inference error (RMSE): ±2.5550564856167695
# ##### AdaBoostRegressor - LassoCV #####
# Train MSE: 3.144
# Train inference error (RMSE): ±1.7731188117860168
# Test MSE: 5.637
# Test inference error (RMSE): ±2.374286505149821
# ##### AdaBoostRegressor - LassoLars #####
# Train MSE: 3.351
# Train inference error (RMSE): ±1.8306793299930202
# Test MSE: 6.870
# Test inference error (RMSE): ±2.621010649598715
# ##### AdaBoostRegressor - LassoLarsCV #####
# Train MSE: 2.869
# Train inference error (RMSE): ±1.69368916957247
# Test MSE: 5.349
# Test inference error (RMSE): ±2.312879202471293
# ##### AdaBoostRegressor - LassoLarsIC #####
# Train MSE: 2.923
# Train inference error (RMSE): ±1.7096774775195627
# Test MSE: 5.514
# Test inference error (RMSE): ±2.3482236423791134
# ##### AdaBoostRegressor - LinearRegression #####
# Train MSE: 3.288
# Train inference error (RMSE): ±1.813157184618155
# Test MSE: 5.915
# Test inference error (RMSE): ±2.432132399515009
# ##### AdaBoostRegressor - LinearSVR #####
# Train MSE: 2.815
# Train inference error (RMSE): ±1.677848569454901
# Test MSE: 5.291
# Test inference error (RMSE): ±2.3002385747355953
# ##### AdaBoostRegressor - MLPRegressor #####
# Train MSE: 1.819
# Train inference error (RMSE): ±1.348707017672648
# Test MSE: 3.109
# Test inference error (RMSE): ±1.7633077002859365
# ##### AdaBoostRegressor - MultiTaskElasticNet #####
# Error (AdaBoostRegressor-MultiTaskElasticNet): For mono-task outputs, use ElasticNet
# ##### AdaBoostRegressor - MultiTaskElasticNetCV #####
# Error (AdaBoostRegressor-MultiTaskElasticNetCV): For mono-task outputs, use ElasticNetCVCV
# ##### AdaBoostRegressor - MultiTaskLasso #####
# Error (AdaBoostRegressor-MultiTaskLasso): For mono-task outputs, use ElasticNet
# ##### AdaBoostRegressor - MultiTaskLassoCV #####
# Error (AdaBoostRegressor-MultiTaskLassoCV): For mono-task outputs, use LassoCVCV
# ##### AdaBoostRegressor - NuSVR #####
# Train MSE: 2.404
# Train inference error (RMSE): ±1.5505033263868575
# Test MSE: 4.058
# Test inference error (RMSE): ±2.014463187063742
# ##### AdaBoostRegressor - OrthogonalMatchingPursuit #####
# Train MSE: 2.719
# Train inference error (RMSE): ±1.649009082123719
# Test MSE: 5.255
# Test inference error (RMSE): ±2.2924828243783164
# ##### AdaBoostRegressor - OrthogonalMatchingPursuitCV #####
# Train MSE: 3.042
# Train inference error (RMSE): ±1.7440072770061321
# Test MSE: 6.081
# Test inference error (RMSE): ±2.4659500392491167
# ##### AdaBoostRegressor - PLSCanonical #####
# Error (AdaBoostRegressor-PLSCanonical): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### AdaBoostRegressor - PLSRegression #####
# Train MSE: 3.137
# Train inference error (RMSE): ±1.7710999178318945
# Test MSE: 5.841
# Test inference error (RMSE): ±2.4167555471421616
# ##### AdaBoostRegressor - PassiveAggressiveRegressor #####
# Train MSE: 3.372
# Train inference error (RMSE): ±1.8363649127299821
# Test MSE: 7.440
# Test inference error (RMSE): ±2.7276983318090564
# ##### AdaBoostRegressor - PoissonRegressor #####
# Error (AdaBoostRegressor-PoissonRegressor): Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# ##### AdaBoostRegressor - QuantileRegressor #####
# Train MSE: 3.546
# Train inference error (RMSE): ±1.8831535641257788
# Test MSE: 7.397
# Test inference error (RMSE): ±2.7196839437109026
# ##### AdaBoostRegressor - RANSACRegressor #####
# Train MSE: 2.693
# Train inference error (RMSE): ±1.6411035251430222
# Test MSE: 5.185
# Test inference error (RMSE): ±2.277029242837773
# ##### AdaBoostRegressor - RadiusNeighborsRegressor #####
# Error (AdaBoostRegressor-RadiusNeighborsRegressor): Input X contains NaN.
# _RidgeGCV does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# ##### AdaBoostRegressor - RandomForestRegressor #####
# Train MSE: 0.678
# Train inference error (RMSE): ±0.8235060820820804
# Test MSE: 4.512
# Test inference error (RMSE): ±2.1241356876120707
# ##### AdaBoostRegressor - Ridge #####
# Train MSE: 2.939
# Train inference error (RMSE): ±1.7143369381226854
# Test MSE: 5.675
# Test inference error (RMSE): ±2.3821784334237264
# ##### AdaBoostRegressor - RidgeCV #####
# Train MSE: 3.208
# Train inference error (RMSE): ±1.7911284023297447
# Test MSE: 5.837
# Test inference error (RMSE): ±2.416083155503509
# ##### AdaBoostRegressor - SGDRegressor #####
# Train MSE: 2.918
# Train inference error (RMSE): ±1.7082800511580858
# Test MSE: 5.689
# Test inference error (RMSE): ±2.3852244952095805
# ##### AdaBoostRegressor - SVR #####
# Train MSE: 2.256
# Train inference error (RMSE): ±1.50188955855859
# Test MSE: 3.862
# Test inference error (RMSE): ±1.9652939708026878
# ##### AdaBoostRegressor - TheilSenRegressor #####
# Train MSE: 3.121
# Train inference error (RMSE): ±1.7666481867615478
# Test MSE: 5.851
# Test inference error (RMSE): ±2.418827617764801
# ##### AdaBoostRegressor - TransformedTargetRegressor #####
# Train MSE: 2.900
# Train inference error (RMSE): ±1.7029081149113334
# Test MSE: 5.347
# Test inference error (RMSE): ±2.3123900597253884
# ##### AdaBoostRegressor - TweedieRegressor #####
# Train MSE: 3.034
# Train inference error (RMSE): ±1.7418552740825828
# Test MSE: 5.609
# Test inference error (RMSE): ±2.368333221371316
# ##### BaggingRegressor - BayesianRidge #####
# Train MSE: 1.561
# Train inference error (RMSE): ±1.2495595486500335
# Test MSE: 4.887
# Test inference error (RMSE): ±2.210551535548448
# ##### BaggingRegressor - CCA #####
# Error (BaggingRegressor-CCA): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### BaggingRegressor - DecisionTreeRegressor #####
# Train MSE: 0.912
# Train inference error (RMSE): ±0.9551382682376137
# Test MSE: 5.877
# Test inference error (RMSE): ±2.424332443158467
# ##### BaggingRegressor - DummyRegressor #####
# Train MSE: 0.854
# Train inference error (RMSE): ±0.9242822291516185
# Test MSE: 5.176
# Test inference error (RMSE): ±2.275124162865729
# ##### BaggingRegressor - ElasticNet #####
# Train MSE: 1.487
# Train inference error (RMSE): ±1.2194132819354668
# Test MSE: 5.831
# Test inference error (RMSE): ±2.4148414764532133
# ##### BaggingRegressor - ElasticNetCV #####
# Train MSE: 1.628
# Train inference error (RMSE): ±1.2757837354316472
# Test MSE: 5.511
# Test inference error (RMSE): ±2.3474958539024517
# ##### BaggingRegressor - ExtraTreeRegressor #####
# Train MSE: 0.546
# Train inference error (RMSE): ±0.7386250925744822
# Test MSE: 5.863
# Test inference error (RMSE): ±2.421341467013757
# ##### BaggingRegressor - ExtraTreesRegressor #####
# Train MSE: 0.624
# Train inference error (RMSE): ±0.7897059631853647
# Test MSE: 4.085
# Test inference error (RMSE): ±2.0212095029539143
# ##### BaggingRegressor - GammaRegressor #####
# Error (BaggingRegressor-GammaRegressor): Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
# ##### BaggingRegressor - GaussianProcessRegressor #####
# Train MSE: 0.954
# Train inference error (RMSE): ±0.9768721640009105
# Test MSE: 4.776
# Test inference error (RMSE): ±2.185438942085234
# ##### BaggingRegressor - GradientBoostingRegressor #####
# Train MSE: 0.632
# Train inference error (RMSE): ±0.7950625345475394
# Test MSE: 3.340
# Test inference error (RMSE): ±1.8275002975412262
# ##### BaggingRegressor - HistGradientBoostingRegressor #####
# Train MSE: 0.768
# Train inference error (RMSE): ±0.8764313791037307
# Test MSE: 3.463
# Test inference error (RMSE): ±1.8608615017683925
# ##### BaggingRegressor - HuberRegressor #####
# Train MSE: 1.796
# Train inference error (RMSE): ±1.3402016787774975
# Test MSE: 5.084
# Test inference error (RMSE): ±2.254852313355498
# ##### BaggingRegressor - IsotonicRegression #####
# Error (BaggingRegressor-IsotonicRegression): Isotonic regression input X should be a 1d array or 2d array with 1 feature
# ##### BaggingRegressor - KNeighborsRegressor #####
# Train MSE: 1.264
# Train inference error (RMSE): ±1.1242435502487595
# Test MSE: 3.824
# Test inference error (RMSE): ±1.9556017024465349
# ##### BaggingRegressor - KernelRidge #####
# Train MSE: 1.711
# Train inference error (RMSE): ±1.3080859853761158
# Test MSE: 5.410
# Test inference error (RMSE): ±2.3259545538977506
# ##### BaggingRegressor - Lars #####
# Train MSE: 1.830
# Train inference error (RMSE): ±1.3527964436559516
# Test MSE: 5.189
# Test inference error (RMSE): ±2.278016043265431
# ##### BaggingRegressor - LarsCV #####
# Train MSE: 1.849
# Train inference error (RMSE): ±1.359693502251769
# Test MSE: 5.153
# Test inference error (RMSE): ±2.2701178086595286
# ##### BaggingRegressor - Lasso #####
# Train MSE: 1.336
# Train inference error (RMSE): ±1.155903884334362
# Test MSE: 5.450
# Test inference error (RMSE): ±2.334561772293412
# ##### BaggingRegressor - LassoCV #####
# Train MSE: 1.770
# Train inference error (RMSE): ±1.3304372923492316
# Test MSE: 5.682
# Test inference error (RMSE): ±2.38375299061407
# ##### BaggingRegressor - LassoLars #####
# Train MSE: 1.470
# Train inference error (RMSE): ±1.2122414990413277
# Test MSE: 5.966
# Test inference error (RMSE): ±2.4426348229711556
# ##### BaggingRegressor - LassoLarsCV #####
# Train MSE: 1.736
# Train inference error (RMSE): ±1.3176769843784801
# Test MSE: 5.482
# Test inference error (RMSE): ±2.341444150956368
# ##### BaggingRegressor - LassoLarsIC #####
# Train MSE: 1.648
# Train inference error (RMSE): ±1.2835853463532467
# Test MSE: 5.449
# Test inference error (RMSE): ±2.3343531877525385
# ##### BaggingRegressor - LinearRegression #####
# Train MSE: 1.563
# Train inference error (RMSE): ±1.250271476884633
# Test MSE: 5.145
# Test inference error (RMSE): ±2.268149308044215
# ##### BaggingRegressor - LinearSVR #####
# Train MSE: 1.923
# Train inference error (RMSE): ±1.386603311679565
# Test MSE: 5.170
# Test inference error (RMSE): ±2.2737272497394723
# ##### BaggingRegressor - MLPRegressor #####
# Train MSE: 1.596
# Train inference error (RMSE): ±1.263167320993001
# Test MSE: 2.938
# Test inference error (RMSE): ±1.7140143988074186
# ##### BaggingRegressor - MultiTaskElasticNet #####
# Error (BaggingRegressor-MultiTaskElasticNet): For mono-task outputs, use ElasticNet
# ##### BaggingRegressor - MultiTaskElasticNetCV #####
# Error (BaggingRegressor-MultiTaskElasticNetCV): For mono-task outputs, use ElasticNetCVCV
# ##### BaggingRegressor - MultiTaskLasso #####
# Error (BaggingRegressor-MultiTaskLasso): For mono-task outputs, use ElasticNet
# ##### BaggingRegressor - MultiTaskLassoCV #####
# Error (BaggingRegressor-MultiTaskLassoCV): For mono-task outputs, use LassoCVCV
# ##### BaggingRegressor - NuSVR #####
# Train MSE: 2.218
# Train inference error (RMSE): ±1.4894217659366649
# Test MSE: 3.883
# Test inference error (RMSE): ±1.9704778249334658
# ##### BaggingRegressor - OrthogonalMatchingPursuit #####
# Train MSE: 0.941
# Train inference error (RMSE): ±0.9699465705627532
# Test MSE: 5.119
# Test inference error (RMSE): ±2.262581849647467
# ##### BaggingRegressor - OrthogonalMatchingPursuitCV #####
# Train MSE: 1.818
# Train inference error (RMSE): ±1.3482523361279852
# Test MSE: 5.817
# Test inference error (RMSE): ±2.411754198532181
# ##### BaggingRegressor - PLSCanonical #####
# Error (BaggingRegressor-PLSCanonical): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### BaggingRegressor - PLSRegression #####
# Train MSE: 1.711
# Train inference error (RMSE): ±1.308093261467817
# Test MSE: 5.572
# Test inference error (RMSE): ±2.3606083859476494
# ##### BaggingRegressor - PassiveAggressiveRegressor #####
# Train MSE: 1.093
# Train inference error (RMSE): ±1.0453039518954654
# Test MSE: 5.376
# Test inference error (RMSE): ±2.318547187741382
# ##### BaggingRegressor - PoissonRegressor #####
# Error (BaggingRegressor-PoissonRegressor): Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# ##### BaggingRegressor - QuantileRegressor #####
# Train MSE: 0.946
# Train inference error (RMSE): ±0.9723861332176262
# Test MSE: 5.747
# Test inference error (RMSE): ±2.3973610321028325
# ##### BaggingRegressor - RANSACRegressor #####
# Train MSE: 1.322
# Train inference error (RMSE): ±1.1499736796864968
# Test MSE: 4.934
# Test inference error (RMSE): ±2.221166215926747
# ##### BaggingRegressor - RadiusNeighborsRegressor #####
# Error (BaggingRegressor-RadiusNeighborsRegressor): Input X contains NaN.
# _RidgeGCV does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# ##### BaggingRegressor - RandomForestRegressor #####
# Train MSE: 0.520
# Train inference error (RMSE): ±0.7207714357952996
# Test MSE: 4.813
# Test inference error (RMSE): ±2.193775265780686
# ##### BaggingRegressor - Ridge #####
# Train MSE: 1.795
# Train inference error (RMSE): ±1.3397710900362678
# Test MSE: 5.163
# Test inference error (RMSE): ±2.2721541773687597
# ##### BaggingRegressor - RidgeCV #####
# Train MSE: 2.240
# Train inference error (RMSE): ±1.496753750506682
# Test MSE: 5.247
# Test inference error (RMSE): ±2.2905559995040994
# ##### BaggingRegressor - SGDRegressor #####
# Train MSE: 2.117
# Train inference error (RMSE): ±1.45509651859497
# Test MSE: 5.056
# Test inference error (RMSE): ±2.2484877733883324
# ##### BaggingRegressor - SVR #####
# Train MSE: 2.122
# Train inference error (RMSE): ±1.4566483154723182
# Test MSE: 3.753
# Test inference error (RMSE): ±1.9373209435763559
# ##### BaggingRegressor - TheilSenRegressor #####
# Train MSE: 1.532
# Train inference error (RMSE): ±1.2379282552693196
# Test MSE: 5.012
# Test inference error (RMSE): ±2.2388479953232276
# ##### BaggingRegressor - TransformedTargetRegressor #####
# Train MSE: 1.666
# Train inference error (RMSE): ±1.2908178036324163
# Test MSE: 5.138
# Test inference error (RMSE): ±2.2667661385548974
# ##### BaggingRegressor - TweedieRegressor #####
# Train MSE: 2.157
# Train inference error (RMSE): ±1.4687999911162801
# Test MSE: 5.351
# Test inference error (RMSE): ±2.3132886528036276
# ##### BayesianRidge - CCA #####
# Error (BayesianRidge-CCA): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### BayesianRidge - DecisionTreeRegressor #####
# Train MSE: 4.323
# Train inference error (RMSE): ±2.0791937265996716
# Test MSE: 6.301
# Test inference error (RMSE): ±2.510088909209285
# ##### BayesianRidge - DummyRegressor #####
# Train MSE: 5.868
# Train inference error (RMSE): ±2.422337574433988
# Test MSE: 7.056
# Test inference error (RMSE): ±2.656259744696043
# ##### BayesianRidge - ElasticNet #####
# Train MSE: 5.867
# Train inference error (RMSE): ±2.4221923505609118
# Test MSE: 7.048
# Test inference error (RMSE): ±2.654871743041944
# ##### BayesianRidge - ElasticNetCV #####
# Train MSE: 5.867
# Train inference error (RMSE): ±2.422196442089625
# Test MSE: 7.054
# Test inference error (RMSE): ±2.6558559289632706
# ##### BayesianRidge - ExtraTreeRegressor #####
# Train MSE: 3.236
# Train inference error (RMSE): ±1.7988519330130317
# Test MSE: 6.648
# Test inference error (RMSE): ±2.578464749131124
# ##### BayesianRidge - ExtraTreesRegressor #####
# Train MSE: 0.488
# Train inference error (RMSE): ±0.6984248245515696
# Test MSE: 3.801
# Test inference error (RMSE): ±1.949584826980534
# ##### BayesianRidge - GammaRegressor #####
# Error (BayesianRidge-GammaRegressor): Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
# ##### BayesianRidge - GaussianProcessRegressor #####
# Train MSE: 1.106
# Train inference error (RMSE): ±1.0516542132106756
# Test MSE: 4.672
# Test inference error (RMSE): ±2.161469093907008
# ##### BayesianRidge - GradientBoostingRegressor #####
# Train MSE: 0.662
# Train inference error (RMSE): ±0.8136460369299919
# Test MSE: 3.404
# Test inference error (RMSE): ±1.8449096715468112
# ##### BayesianRidge - HistGradientBoostingRegressor #####
# Train MSE: 0.773
# Train inference error (RMSE): ±0.8791936222609686
# Test MSE: 3.475
# Test inference error (RMSE): ±1.8640079801274607
# ##### BayesianRidge - HuberRegressor #####
# Train MSE: 5.881
# Train inference error (RMSE): ±2.425120833709791
# Test MSE: 7.027
# Test inference error (RMSE): ±2.6507706390105077
# ##### BayesianRidge - IsotonicRegression #####
# Error (BayesianRidge-IsotonicRegression): Isotonic regression input X should be a 1d array or 2d array with 1 feature
# ##### BayesianRidge - KNeighborsRegressor #####
# Train MSE: 3.649
# Train inference error (RMSE): ±1.9103330930641997
# Test MSE: 4.860
# Test inference error (RMSE): ±2.204569605342965
# ##### BayesianRidge - KernelRidge #####
# Train MSE: 5.870
# Train inference error (RMSE): ±2.422748409097662
# Test MSE: 7.054
# Test inference error (RMSE): ±2.6559356217557544
# ##### BayesianRidge - Lars #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.42198341684573
# Test MSE: 7.055
# Test inference error (RMSE): ±2.6561527976054005
# ##### BayesianRidge - LarsCV #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.42198341684573
# Test MSE: 7.055
# Test inference error (RMSE): ±2.6561527976054005
# ##### BayesianRidge - Lasso #####
# Train MSE: 5.869
# Train inference error (RMSE): ±2.422526620867249
# Test MSE: 7.025
# Test inference error (RMSE): ±2.6505383606032415
# ##### BayesianRidge - LassoCV #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.42207438171446
# Test MSE: 7.054
# Test inference error (RMSE): ±2.656000710617703
# ##### BayesianRidge - LassoLars #####
# Train MSE: 5.869
# Train inference error (RMSE): ±2.422526621341129
# Test MSE: 7.025
# Test inference error (RMSE): ±2.6505383578763597
# ##### BayesianRidge - LassoLarsCV #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.42198341684573
# Test MSE: 7.055
# Test inference error (RMSE): ±2.6561527976054005
# ##### BayesianRidge - LassoLarsIC #####
# Train MSE: 5.885
# Train inference error (RMSE): ±2.425934336577226
# Test MSE: 7.063
# Test inference error (RMSE): ±2.657554975181184
# ##### BayesianRidge - LinearRegression #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.42198341684573
# Test MSE: 7.055
# Test inference error (RMSE): ±2.6561527976054022
# ##### BayesianRidge - LinearSVR #####
# Train MSE: 5.872
# Train inference error (RMSE): ±2.423305530210475
# Test MSE: 7.031
# Test inference error (RMSE): ±2.651585756378324
# ##### BayesianRidge - MLPRegressor #####
# Train MSE: 1.983
# Train inference error (RMSE): ±1.4081110049149024
# Test MSE: 3.027
# Test inference error (RMSE): ±1.7398878751893292
# ##### BayesianRidge - MultiTaskElasticNet #####
# Error (BayesianRidge-MultiTaskElasticNet): For mono-task outputs, use ElasticNet
# ##### BayesianRidge - MultiTaskElasticNetCV #####
# Error (BayesianRidge-MultiTaskElasticNetCV): For mono-task outputs, use ElasticNetCVCV
# ##### BayesianRidge - MultiTaskLasso #####
# Error (BayesianRidge-MultiTaskLasso): For mono-task outputs, use ElasticNet
# ##### BayesianRidge - MultiTaskLassoCV #####
# Error (BayesianRidge-MultiTaskLassoCV): For mono-task outputs, use LassoCVCV
# ##### BayesianRidge - NuSVR #####
# Train MSE: 3.385
# Train inference error (RMSE): ±1.839769862115817
# Test MSE: 4.080
# Test inference error (RMSE): ±2.01997868214111
# ##### BayesianRidge - OrthogonalMatchingPursuit #####
# Train MSE: 5.867
# Train inference error (RMSE): ±2.4222840035480595
# Test MSE: 7.034
# Test inference error (RMSE): ±2.6520886360137377
# ##### BayesianRidge - OrthogonalMatchingPursuitCV #####
# Train MSE: 5.877
# Train inference error (RMSE): ±2.4242525626832765
# Test MSE: 7.057
# Test inference error (RMSE): ±2.656593206737416
# ##### BayesianRidge - PLSCanonical #####
# Error (BayesianRidge-PLSCanonical): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### BayesianRidge - PLSRegression #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.4219968179224365
# Test MSE: 7.053
# Test inference error (RMSE): ±2.655663731593259
# ##### BayesianRidge - PassiveAggressiveRegressor #####
# Train MSE: 5.867
# Train inference error (RMSE): ±2.422260084847596
# Test MSE: 7.051
# Test inference error (RMSE): ±2.65545420868775
# ##### BayesianRidge - PoissonRegressor #####
# Error (BayesianRidge-PoissonRegressor): Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# ##### BayesianRidge - QuantileRegressor #####
# Train MSE: 5.868
# Train inference error (RMSE): ±2.4223134653114005
# Test MSE: 7.055
# Test inference error (RMSE): ±2.6561899565250893
# ##### BayesianRidge - RANSACRegressor #####
# Train MSE: 5.906
# Train inference error (RMSE): ±2.430324929987604
# Test MSE: 7.019
# Test inference error (RMSE): ±2.6493995693728496
# ##### BayesianRidge - RadiusNeighborsRegressor #####
# Error (BayesianRidge-RadiusNeighborsRegressor): Input X contains NaN.
# _RidgeGCV does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# ##### BayesianRidge - RandomForestRegressor #####
# Train MSE: 0.949
# Train inference error (RMSE): ±0.974310352438094
# Test MSE: 4.594
# Test inference error (RMSE): ±2.1433987852771446
# ##### BayesianRidge - Ridge #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.4220364899566063
# Test MSE: 7.054
# Test inference error (RMSE): ±2.6559637418956217
# ##### BayesianRidge - RidgeCV #####
# Train MSE: 5.894
# Train inference error (RMSE): ±2.427820003591414
# Test MSE: 7.091
# Test inference error (RMSE): ±2.6629166132478024
# ##### BayesianRidge - SGDRegressor #####
# Train MSE: 5.870
# Train inference error (RMSE): ±2.422829200146069
# Test MSE: 7.056
# Test inference error (RMSE): ±2.6562236746347043
# ##### BayesianRidge - SVR #####
# Train MSE: 3.464
# Train inference error (RMSE): ±1.8612408896517325
# Test MSE: 3.942
# Test inference error (RMSE): ±1.985565914798009
# ##### BayesianRidge - TheilSenRegressor #####
# Train MSE: 5.881
# Train inference error (RMSE): ±2.425132170708805
# Test MSE: 7.063
# Test inference error (RMSE): ±2.657663036692523
# ##### BayesianRidge - TransformedTargetRegressor #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.42198341684573
# Test MSE: 7.055
# Test inference error (RMSE): ±2.6561527976054022
# ##### BayesianRidge - TweedieRegressor #####
# Train MSE: 5.867
# Train inference error (RMSE): ±2.422129278324745
# Test MSE: 7.052
# Test inference error (RMSE): ±2.6555363792923874
# ##### CCA - DecisionTreeRegressor #####
# Error (CCA-DecisionTreeRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - DummyRegressor #####
# Error (CCA-DummyRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - ElasticNet #####
# Error (CCA-ElasticNet): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - ElasticNetCV #####
# Error (CCA-ElasticNetCV): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - ExtraTreeRegressor #####
# Error (CCA-ExtraTreeRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - ExtraTreesRegressor #####
# Error (CCA-ExtraTreesRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - GammaRegressor #####
# Error (CCA-GammaRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - GaussianProcessRegressor #####
# Error (CCA-GaussianProcessRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - GradientBoostingRegressor #####
# Error (CCA-GradientBoostingRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - HistGradientBoostingRegressor #####
# Error (CCA-HistGradientBoostingRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - HuberRegressor #####
# Error (CCA-HuberRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - IsotonicRegression #####
# Error (CCA-IsotonicRegression): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - KNeighborsRegressor #####
# Error (CCA-KNeighborsRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - KernelRidge #####
# Error (CCA-KernelRidge): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - Lars #####
# Error (CCA-Lars): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - LarsCV #####
# Error (CCA-LarsCV): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - Lasso #####
# Error (CCA-Lasso): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - LassoCV #####
# Error (CCA-LassoCV): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - LassoLars #####
# Error (CCA-LassoLars): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - LassoLarsCV #####
# Error (CCA-LassoLarsCV): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - LassoLarsIC #####
# Error (CCA-LassoLarsIC): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - LinearRegression #####
# Error (CCA-LinearRegression): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - LinearSVR #####
# Error (CCA-LinearSVR): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - MLPRegressor #####
# Error (CCA-MLPRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - MultiTaskElasticNet #####
# Error (CCA-MultiTaskElasticNet): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - MultiTaskElasticNetCV #####
# Error (CCA-MultiTaskElasticNetCV): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - MultiTaskLasso #####
# Error (CCA-MultiTaskLasso): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - MultiTaskLassoCV #####
# Error (CCA-MultiTaskLassoCV): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - NuSVR #####
# Error (CCA-NuSVR): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - OrthogonalMatchingPursuit #####
# Error (CCA-OrthogonalMatchingPursuit): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - OrthogonalMatchingPursuitCV #####
# Error (CCA-OrthogonalMatchingPursuitCV): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - PLSCanonical #####
# Error (CCA-PLSCanonical): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - PLSRegression #####
# Error (CCA-PLSRegression): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - PassiveAggressiveRegressor #####
# Error (CCA-PassiveAggressiveRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - PoissonRegressor #####
# Error (CCA-PoissonRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - QuantileRegressor #####
# Error (CCA-QuantileRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - RANSACRegressor #####
# Error (CCA-RANSACRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - RadiusNeighborsRegressor #####
# Error (CCA-RadiusNeighborsRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - RandomForestRegressor #####
# Error (CCA-RandomForestRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - Ridge #####
# Error (CCA-Ridge): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - RidgeCV #####
# Error (CCA-RidgeCV): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - SGDRegressor #####
# Error (CCA-SGDRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - SVR #####
# Error (CCA-SVR): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - TheilSenRegressor #####
# Error (CCA-TheilSenRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - TransformedTargetRegressor #####
# Error (CCA-TransformedTargetRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### CCA - TweedieRegressor #####
# Error (CCA-TweedieRegressor): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### DecisionTreeRegressor - DummyRegressor #####
# Train MSE: 2.089
# Train inference error (RMSE): ±1.4454965648634683
# Test MSE: 9.274
# Test inference error (RMSE): ±3.0452933300758795
# ##### DecisionTreeRegressor - ElasticNet #####
# Train MSE: 4.606
# Train inference error (RMSE): ±2.1462020591555255
# Test MSE: 6.904
# Test inference error (RMSE): ±2.6276371065670374
# ##### DecisionTreeRegressor - ElasticNetCV #####
# Train MSE: 4.416
# Train inference error (RMSE): ±2.101333039717874
# Test MSE: 6.314
# Test inference error (RMSE): ±2.512821764229921
# ##### DecisionTreeRegressor - ExtraTreeRegressor #####
# Train MSE: 0.369
# Train inference error (RMSE): ±0.6076959382718308
# Test MSE: 7.830
# Test inference error (RMSE): ±2.7981471379242944
# ##### DecisionTreeRegressor - ExtraTreesRegressor #####
# Train MSE: 0.647
# Train inference error (RMSE): ±0.8044851292716559
# Test MSE: 4.330
# Test inference error (RMSE): ±2.0807907951217706
# ##### DecisionTreeRegressor - GammaRegressor #####
# Error (DecisionTreeRegressor-GammaRegressor): Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
# ##### DecisionTreeRegressor - GaussianProcessRegressor #####
# Train MSE: 1.272
# Train inference error (RMSE): ±1.1277540253256189
# Test MSE: 4.781
# Test inference error (RMSE): ±2.186623477832489
# ##### DecisionTreeRegressor - GradientBoostingRegressor #####
# Train MSE: 0.726
# Train inference error (RMSE): ±0.8521019888128216
# Test MSE: 3.502
# Test inference error (RMSE): ±1.871385619981687
# ##### DecisionTreeRegressor - HistGradientBoostingRegressor #####
# Train MSE: 0.823
# Train inference error (RMSE): ±0.9069640171716093
# Test MSE: 3.499
# Test inference error (RMSE): ±1.8704823012835101
# ##### DecisionTreeRegressor - HuberRegressor #####
# Train MSE: 4.180
# Train inference error (RMSE): ±2.0445753531758095
# Test MSE: 6.242
# Test inference error (RMSE): ±2.4983098852062993
# ##### DecisionTreeRegressor - IsotonicRegression #####
# Error (DecisionTreeRegressor-IsotonicRegression): Isotonic regression input X should be a 1d array or 2d array with 1 feature
# ##### DecisionTreeRegressor - KNeighborsRegressor #####
# Train MSE: 2.386
# Train inference error (RMSE): ±1.5446090825335441
# Test MSE: 4.363
# Test inference error (RMSE): ±2.088875075676175
# ##### DecisionTreeRegressor - KernelRidge #####
# Train MSE: 4.393
# Train inference error (RMSE): ±2.0960199135727344
# Test MSE: 6.233
# Test inference error (RMSE): ±2.496580843332247
# ##### DecisionTreeRegressor - Lars #####
# Train MSE: 4.236
# Train inference error (RMSE): ±2.058095059486275
# Test MSE: 6.180
# Test inference error (RMSE): ±2.485920505729298
# ##### DecisionTreeRegressor - LarsCV #####
# Train MSE: 4.065
# Train inference error (RMSE): ±2.0161404075491887
# Test MSE: 6.126
# Test inference error (RMSE): ±2.475108744210391
# ##### DecisionTreeRegressor - Lasso #####
# Train MSE: 4.564
# Train inference error (RMSE): ±2.136348890411689
# Test MSE: 8.080
# Test inference error (RMSE): ±2.8425332639162484
# ##### DecisionTreeRegressor - LassoCV #####
# Train MSE: 4.442
# Train inference error (RMSE): ±2.107527854423068
# Test MSE: 6.293
# Test inference error (RMSE): ±2.508603051620822
# ##### DecisionTreeRegressor - LassoLars #####
# Train MSE: 4.318
# Train inference error (RMSE): ±2.078042772896326
# Test MSE: 7.569
# Test inference error (RMSE): ±2.751142826153089
# ##### DecisionTreeRegressor - LassoLarsCV #####
# Train MSE: 4.375
# Train inference error (RMSE): ±2.0916067224590447
# Test MSE: 6.240
# Test inference error (RMSE): ±2.4979206610465954
# ##### DecisionTreeRegressor - LassoLarsIC #####
# Train MSE: 3.884
# Train inference error (RMSE): ±1.9707388252931541
# Test MSE: 6.059
# Test inference error (RMSE): ±2.461444786826625
# ##### DecisionTreeRegressor - LinearRegression #####
# Train MSE: 4.182
# Train inference error (RMSE): ±2.0449355107205327
# Test MSE: 6.220
# Test inference error (RMSE): ±2.4940857099419786
# ##### DecisionTreeRegressor - LinearSVR #####
# Train MSE: 4.381
# Train inference error (RMSE): ±2.0931847272014514
# Test MSE: 6.310
# Test inference error (RMSE): ±2.511998728197551
# ##### DecisionTreeRegressor - MLPRegressor #####
# Train MSE: 2.171
# Train inference error (RMSE): ±1.4734970162292522
# Test MSE: 3.059
# Test inference error (RMSE): ±1.7489868183795119
# ##### DecisionTreeRegressor - MultiTaskElasticNet #####
# Error (DecisionTreeRegressor-MultiTaskElasticNet): For mono-task outputs, use ElasticNet
# ##### DecisionTreeRegressor - MultiTaskElasticNetCV #####
# Error (DecisionTreeRegressor-MultiTaskElasticNetCV): For mono-task outputs, use ElasticNetCVCV
# ##### DecisionTreeRegressor - MultiTaskLasso #####
# Error (DecisionTreeRegressor-MultiTaskLasso): For mono-task outputs, use ElasticNet
# ##### DecisionTreeRegressor - MultiTaskLassoCV #####
# Error (DecisionTreeRegressor-MultiTaskLassoCV): For mono-task outputs, use LassoCVCV
# ##### DecisionTreeRegressor - NuSVR #####
# Train MSE: 3.144
# Train inference error (RMSE): ±1.773054389458565
# Test MSE: 4.104
# Test inference error (RMSE): ±2.025749088052568
# ##### DecisionTreeRegressor - OrthogonalMatchingPursuit #####
# Train MSE: 2.756
# Train inference error (RMSE): ±1.6601376164152843
# Test MSE: 9.912
# Test inference error (RMSE): ±3.1482923227016775
# ##### DecisionTreeRegressor - OrthogonalMatchingPursuitCV #####
# Train MSE: 4.455
# Train inference error (RMSE): ±2.1107296403981763
# Test MSE: 6.573
# Test inference error (RMSE): ±2.5637187918994457
# ##### DecisionTreeRegressor - PLSCanonical #####
# Error (DecisionTreeRegressor-PLSCanonical): `n_components` upper bound is 1. Got 2 instead. Reduce `n_components`.
# ##### DecisionTreeRegressor - PLSRegression #####
# Train MSE: 4.457
# Train inference error (RMSE): ±2.111198516566808
# Test MSE: 6.296
# Test inference error (RMSE): ±2.5091845099676164
# ##### DecisionTreeRegressor - PassiveAggressiveRegressor #####
# Train MSE: 5.448
# Train inference error (RMSE): ±2.334159323692487
# Test MSE: 10.100
# Test inference error (RMSE): ±3.178092961799391
# ##### DecisionTreeRegressor - PoissonRegressor #####
# Error (DecisionTreeRegressor-PoissonRegressor): Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# ##### DecisionTreeRegressor - QuantileRegressor #####
# Train MSE: 2.206
# Train inference error (RMSE): ±1.4853217345771528
# Test MSE: 10.398
# Test inference error (RMSE): ±3.224640706596156
# ##### DecisionTreeRegressor - RANSACRegressor #####
# Train MSE: 3.365
# Train inference error (RMSE): ±1.8344052566793487
# Test MSE: 6.012
# Test inference error (RMSE): ±2.4519161082614196
# ##### DecisionTreeRegressor - RadiusNeighborsRegressor #####
# ...
# ##### PoissonRegressor - TheilSenRegressor #####
# Error (PoissonRegressor-TheilSenRegressor): Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# ##### PoissonRegressor - TransformedTargetRegressor #####
# Error (PoissonRegressor-TransformedTargetRegressor): Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# ##### PoissonRegressor - TweedieRegressor #####
# Error (PoissonRegressor-TweedieRegressor): Some value(s) of y are out of the valid range of the loss 'HalfPoissonLoss'.
# ##### QuantileRegressor - RANSACRegressor #####
# Train MSE: 6.359
# Train inference error (RMSE): ±2.521763541638524
# Test MSE: 7.446
# Test inference error (RMSE): ±2.7287849998416824
# ##### QuantileRegressor - RadiusNeighborsRegressor #####
# Error (QuantileRegressor-RadiusNeighborsRegressor): Input X contains NaN.
# _RidgeGCV does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# ##### QuantileRegressor - RandomForestRegressor #####
# Train MSE: 0.493
# Train inference error (RMSE): ±0.7021571517953796
# Test MSE: 4.646
# Test inference error (RMSE): ±2.155464132523372
# ##### QuantileRegressor - Ridge #####
# Train MSE: 5.867
# Train inference error (RMSE): ±2.422132117534607
# Test MSE: 7.058
# Test inference error (RMSE): ±2.6567091928932274
# ##### QuantileRegressor - RidgeCV #####
# Train MSE: 5.865
# Train inference error (RMSE): ±2.421736559223542
# Test MSE: 7.049
# Test inference error (RMSE): ±2.6550649152142936
# ##### QuantileRegressor - SGDRegressor #####
# Train MSE: 5.891
# Train inference error (RMSE): ±2.4272409501042445
# Test MSE: 7.049
# Test inference error (RMSE): ±2.654980410902469
# ##### QuantileRegressor - SVR #####
# Train MSE: 3.515
# Train inference error (RMSE): ±1.8748271038252382
# Test MSE: 4.026
# Test inference error (RMSE): ±2.006600196875166
# ##### QuantileRegressor - TheilSenRegressor #####
# Train MSE: 6.085
# Train inference error (RMSE): ±2.4666961207209557
# Test MSE: 7.308
# Test inference error (RMSE): ±2.7033403928026023
# ##### QuantileRegressor - TransformedTargetRegressor #####
# Train MSE: 5.867
# Train inference error (RMSE): ±2.4221182776785346
# Test MSE: 7.060
# Test inference error (RMSE): ±2.6571449141196912
# ##### QuantileRegressor - TweedieRegressor #####
# Train MSE: 5.896
# Train inference error (RMSE): ±2.428263391586448
# Test MSE: 7.108
# Test inference error (RMSE): ±2.6659927426371275
# ##### RANSACRegressor - RadiusNeighborsRegressor #####
# Error (RANSACRegressor-RadiusNeighborsRegressor): Input X contains NaN.
# _RidgeGCV does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# ##### RANSACRegressor - RandomForestRegressor #####
# Train MSE: 0.749
# Train inference error (RMSE): ±0.8653407839435734
# Test MSE: 4.797
# Test inference error (RMSE): ±2.1901874144904387
# ##### RANSACRegressor - Ridge #####
# Train MSE: 5.868
# Train inference error (RMSE): ±2.422304690367847
# Test MSE: 7.049
# Test inference error (RMSE): ±2.6550802126644695
# ##### RANSACRegressor - RidgeCV #####
# Train MSE: 5.865
# Train inference error (RMSE): ±2.4218246278569273
# Test MSE: 7.053
# Test inference error (RMSE): ±2.655797411746664
# ##### RANSACRegressor - SGDRegressor #####
# Train MSE: 5.911
# Train inference error (RMSE): ±2.4311924100180873
# Test MSE: 7.056
# Test inference error (RMSE): ±2.6562544803917554
# ##### RANSACRegressor - SVR #####
# Train MSE: 3.349
# Train inference error (RMSE): ±1.8300457923446987
# Test MSE: 3.774
# Test inference error (RMSE): ±1.9425660405863436
# ##### RANSACRegressor - TheilSenRegressor #####
# Train MSE: 6.331
# Train inference error (RMSE): ±2.5162147164541357
# Test MSE: 7.798
# Test inference error (RMSE): ±2.7924280853747185
# ##### RANSACRegressor - TransformedTargetRegressor #####
# Train MSE: 5.868
# Train inference error (RMSE): ±2.422447244835056
# Test MSE: 7.062
# Test inference error (RMSE): ±2.6573681386667394
# ##### RANSACRegressor - TweedieRegressor #####
# Train MSE: 5.901
# Train inference error (RMSE): ±2.4292174252824643
# Test MSE: 7.009
# Test inference error (RMSE): ±2.6474791132062214
# ##### RadiusNeighborsRegressor - RandomForestRegressor #####
# Error (RadiusNeighborsRegressor-RandomForestRegressor): Input X contains NaN.
# _RidgeGCV does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# ##### RadiusNeighborsRegressor - Ridge #####
# Error (RadiusNeighborsRegressor-Ridge): Input X contains NaN.
# _RidgeGCV does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# ##### RadiusNeighborsRegressor - RidgeCV #####
# Error (RadiusNeighborsRegressor-RidgeCV): Input X contains NaN.
# _RidgeGCV does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# ##### RadiusNeighborsRegressor - SGDRegressor #####
# Error (RadiusNeighborsRegressor-SGDRegressor): Input X contains NaN.
# _RidgeGCV does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# ##### RadiusNeighborsRegressor - SVR #####
# Error (RadiusNeighborsRegressor-SVR): Input X contains NaN.
# _RidgeGCV does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# ##### RadiusNeighborsRegressor - TheilSenRegressor #####
# Error (RadiusNeighborsRegressor-TheilSenRegressor): Input X contains NaN.
# _RidgeGCV does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# ##### RadiusNeighborsRegressor - TransformedTargetRegressor #####
# Error (RadiusNeighborsRegressor-TransformedTargetRegressor): Input X contains NaN.
# _RidgeGCV does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# ##### RadiusNeighborsRegressor - TweedieRegressor #####
# Error (RadiusNeighborsRegressor-TweedieRegressor): Input X contains NaN.
# _RidgeGCV does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values
# ##### RandomForestRegressor - Ridge #####
# Train MSE: 0.988
# Train inference error (RMSE): ±0.9939090769642194
# Test MSE: 4.792
# Test inference error (RMSE): ±2.1891332419352416
# ##### RandomForestRegressor - RidgeCV #####
# Train MSE: 0.925
# Train inference error (RMSE): ±0.9618218239143187
# Test MSE: 4.683
# Test inference error (RMSE): ±2.1641156533352683
# ##### RandomForestRegressor - SGDRegressor #####
# Train MSE: 0.889
# Train inference error (RMSE): ±0.9427666058551851
# Test MSE: 4.599
# Test inference error (RMSE): ±2.1446325721846073
# ##### RandomForestRegressor - SVR #####
# Train MSE: 1.736
# Train inference error (RMSE): ±1.3175285767033769
# Test MSE: 3.722
# Test inference error (RMSE): ±1.929371961218968
# ##### RandomForestRegressor - TheilSenRegressor #####
# Train MSE: 0.940
# Train inference error (RMSE): ±0.9697810889667343
# Test MSE: 4.727
# Test inference error (RMSE): ±2.1742237506035385
# ##### RandomForestRegressor - TransformedTargetRegressor #####
# Train MSE: 0.918
# Train inference error (RMSE): ±0.9580126397749553
# Test MSE: 4.625
# Test inference error (RMSE): ±2.150567307578512
# ##### RandomForestRegressor - TweedieRegressor #####
# Train MSE: 0.954
# Train inference error (RMSE): ±0.9767664306941215
# Test MSE: 4.661
# Test inference error (RMSE): ±2.1589081802597305
# ##### Ridge - RidgeCV #####
# Train MSE: 5.870
# Train inference error (RMSE): ±2.422900245994972
# Test MSE: 7.067
# Test inference error (RMSE): ±2.6584470121679313
# ##### Ridge - SGDRegressor #####
# Train MSE: 5.868
# Train inference error (RMSE): ±2.422437658123264
# Test MSE: 7.059
# Test inference error (RMSE): ±2.6568081200319456
# ##### Ridge - SVR #####
# Train MSE: 3.465
# Train inference error (RMSE): ±1.8615273695946228
# Test MSE: 3.943
# Test inference error (RMSE): ±1.9857532384144576
# ##### Ridge - TheilSenRegressor #####
# Train MSE: 5.886
# Train inference error (RMSE): ±2.426124351203313
# Test MSE: 7.058
# Test inference error (RMSE): ±2.656764399113548
# ##### Ridge - TransformedTargetRegressor #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.421954790465113
# Test MSE: 7.057
# Test inference error (RMSE): ±2.6564340594836855
# ##### Ridge - TweedieRegressor #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.4220039275052083
# Test MSE: 7.056
# Test inference error (RMSE): ±2.656220193501291
# ##### RidgeCV - SGDRegressor #####
# Train MSE: 5.878
# Train inference error (RMSE): ±2.4243780511337767
# Test MSE: 7.061
# Test inference error (RMSE): ±2.657267443458069
# ##### RidgeCV - SVR #####
# Train MSE: 3.463
# Train inference error (RMSE): ±1.8609902423906235
# Test MSE: 3.942
# Test inference error (RMSE): ±1.9855101607194863
# ##### RidgeCV - TheilSenRegressor #####
# Train MSE: 5.895
# Train inference error (RMSE): ±2.4279225375772846
# Test MSE: 7.066
# Test inference error (RMSE): ±2.658218667706104
# ##### RidgeCV - TransformedTargetRegressor #####
# Train MSE: 5.869
# Train inference error (RMSE): ±2.422634759941594
# Test MSE: 7.068
# Test inference error (RMSE): ±2.658589776103659
# ##### RidgeCV - TweedieRegressor #####
# Train MSE: 5.865
# Train inference error (RMSE): ±2.421685013798226
# Test MSE: 7.048
# Test inference error (RMSE): ±2.65480443167322
# ##### SGDRegressor - SVR #####
# Train MSE: 3.462
# Train inference error (RMSE): ±1.8606703350891465
# Test MSE: 3.953
# Test inference error (RMSE): ±1.9882958097286374
# ##### SGDRegressor - TheilSenRegressor #####
# Train MSE: 5.904
# Train inference error (RMSE): ±2.4298300474726418
# Test MSE: 7.065
# Test inference error (RMSE): ±2.657999580851259
# ##### SGDRegressor - TransformedTargetRegressor #####
# Train MSE: 5.875
# Train inference error (RMSE): ±2.4237910599614785
# Test MSE: 7.071
# Test inference error (RMSE): ±2.659182402463976
# ##### SGDRegressor - TweedieRegressor #####
# Train MSE: 5.897
# Train inference error (RMSE): ±2.428327131314091
# Test MSE: 7.053
# Test inference error (RMSE): ±2.6556596963982826
# ##### SVR - TheilSenRegressor #####
# Train MSE: 3.368
# Train inference error (RMSE): ±1.8353406360887459
# Test MSE: 3.855
# Test inference error (RMSE): ±1.9633503910326846
# ##### SVR - TransformedTargetRegressor #####
# Train MSE: 3.466
# Train inference error (RMSE): ±1.8617252798499928
# Test MSE: 3.944
# Test inference error (RMSE): ±1.985902448971358
# ##### SVR - TweedieRegressor #####
# Train MSE: 3.467
# Train inference error (RMSE): ±1.8620182706225754
# Test MSE: 3.950
# Test inference error (RMSE): ±1.987549566190054
# ##### TheilSenRegressor - TransformedTargetRegressor #####
# Train MSE: 5.878
# Train inference error (RMSE): ±2.4245183972903557
# Test MSE: 7.075
# Test inference error (RMSE): ±2.6599029888982195
# ##### TheilSenRegressor - TweedieRegressor #####
# Train MSE: 5.920
# Train inference error (RMSE): ±2.433065355468665
# Test MSE: 7.113
# Test inference error (RMSE): ±2.6669816939530264
# ##### TransformedTargetRegressor - TweedieRegressor #####
# Train MSE: 5.866
# Train inference error (RMSE): ±2.4219962289458947
# Test MSE: 7.058
# Test inference error (RMSE): ±2.6567326229905213
# ########## Best Estimator ##########
# ['GradientBoostingRegressor-MLPRegressor', 2.6503467475070352, 1.6279885587764538]
# Total time: 311.66297245025635

# %%
estimators_stacked_trained[best_stacked_estimator_name]
# Out:
# StackingRegressor(estimators=[('GradientBoostingRegressor',
#                                GradientBoostingRegressor()),
#                               ('MLPRegressor', MLPRegressor())],
#                   final_estimator=RidgeCV())

# %% [markdown]
# ### Save Estimator stacked

# %%
# Save
pickle.dump(estimators_trained[best_estimator_name], open('results/estimator_sklearn_stacked.sav', 'wb'))

# Scaler
pickle.dump(scaler, open('results/scaler.pkl','wb'))

# Save columns names and informations
data_to_save = {
    'col_names_order': col_names_order,
    'num_col_names': num_col_names,
    'cat_col_names': cat_col_names,
    'date_col_names': date_col_names,
    'target_cols': target_cols,
    'category_mappings': category_mappings,
    'window_size': window_size
}
with open('results/columns_metadata_sklearn_stacked.json', 'w') as json_file:
    json.dump(data_to_save, json_file, indent=4)

# %% [markdown]
# ## Predict

# %%
import json
import pickle

import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %%
# Load
loaded_estimator = pickle.load(open('results/estimator_sklearn_stacked.sav', 'rb'))
# Scaler
loaded_scaler = pickle.load(open('results/scaler.pkl','rb'))
# columns_metadata
columns_metadata = json.load(open('results/columns_metadata_sklearn_stacked.json', 'r'))

# %%
def preprocess_inference_data(new_input, columns_metadata, scaler=None):
    """
    Preprocess the input data for inference based on metadata and scaler for numeric normalization.

    Args:
        new_input (list of list): Data to preprocess (each inner list is a row).
        columns_metadata (dict): Metadata defining column names, types, mappings, and order.
        scaler (StandardScaler): Trained scaler for numerical columns.
    
    Returns:
        list: Preprocessed data ready for inference.
    """
    # Exclude target columns from col_names_order for inference
    target_cols = columns_metadata['target_cols']
    col_names_order = [col for col in columns_metadata['col_names_order'] if col not in target_cols]
    # Transform the new_input into a DataFrame with the correct column order
    df_input = pd.DataFrame(new_input, columns=col_names_order)

    # Convert categorical columns based on category_mappings
    category_mappings = columns_metadata['category_mappings']
    for col in columns_metadata['cat_col_names']:
        if col in df_input.columns and col in category_mappings:
            # Replace string categories with mapped integer IDs
            df_input[col] = df_input[col].map(category_mappings[col])
            if df_input[col].isnull().any():
                raise ValueError(f'Invalid value found in column "{col}" that is not in the category mappings.')

    # Normalize numeric columns using the trained scaler
    num_col_names = columns_metadata['num_col_names']
    if num_col_names and scaler:
        df_input[num_col_names] = scaler.transform(df_input[num_col_names])

    # Ensure date columns are in the correct datetime format
    for col in columns_metadata['date_col_names']:
        if col in df_input.columns:
            df_input[col] = pd.to_datetime(df_input[col], errors='coerce')
            if df_input[col].isnull().any():
                raise ValueError(f'Invalid date value found in column "{col}".')

    # Drop target columns if they exist in the input (not used in inference)
    target_cols = columns_metadata['target_cols']
    df_input = df_input.drop(columns=target_cols, errors='ignore')

    # Convert DataFrame to list of rows for model inference
    processed_data = df_input.values.tolist()

    return processed_data

# %%
new_input = [
    [66.770774, 'A', 129.519443, 157.649826, 6.255495, 0.828523, 1.10, 0.656228]  # target 2.432088
]
new_input_preprocessed = preprocess_inference_data(new_input, columns_metadata, loaded_scaler)
new_input_preprocessed
# Out:
# [[0.5913456317430028,
#   0.0,
#   0.4110141395991193,
#   0.008739577288960425,
#   0.22460001175985816,
#   0.8619025779259767,
#   1.1,
#   0.02725715174129902]]

# %%
target = columns_metadata['target_cols'][0]
clss_to_cat = {}
if target in columns_metadata['category_mappings']:
    for key, value in columns_metadata['category_mappings'][target].items():
        clss_to_cat[value] = key

# %%
tic = time.time()
result = loaded_estimator.predict(new_input_preprocessed)
if clss_to_cat:
    result = clss_to_cat[result[0]]
print(result)
print(f'Total time: {time.time() - tic}')
# Out:
# [3.05217838]
# Total time: 0.00036597251892089844
